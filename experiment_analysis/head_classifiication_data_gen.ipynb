# %%
import sys
sys.path.insert(0, '../src')

# %%
from classify_attention_patterns import load_model
from argparse import Namespace
from run_glue import load_and_cache_examples, set_seed
from model_bert import BertForSequenceClassification, BertForMaskedLM
from config_bert import BertConfig
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
from transformers import BertTokenizer
import numpy as np
import torch
import random
from collections import Counter
import pathlib

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
# Out:
# loading region bounding boxes for computing carbon emissions region, this may take a moment...
#  454/454... rate=522.13 Hz, eta=0:00:00, total=0:00:00, wall=11:04 CETT
# Done!

# %%
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import time
import torch
import pathlib
import numpy as np
import pathlib
import json
import numpy as np
import time
import matplotlib.pyplot as plt

def plot_matrix(mean_matrix, x_labels, y_labels, save_path, x_title='', y_title='', colour_map=plt.cm.OrRd):
    fig, ax = plt.subplots(figsize=(9,8))
    ax.set_xlabel(x_title, labelpad=20)
    ax.set_ylabel(y_title)
    ax.xaxis.set_ticks_position('top')
    ax.xaxis.set_label_position('top')
    ax.set_xticks(range(len(x_labels)))
    ax.set_yticks(range(len(y_labels)))
    ax.set_xticklabels(x_labels)
    ax.set_yticklabels(y_labels)
    ax.imshow(mean_matrix, cmap=colour_map)
    plt.tight_layout()
    fig.savefig(save_path, bbox_inches='tight')
    plt.close(fig)

# %%
set_seed(1337)

save_dir = pathlib.Path("./heatmap_attention_mask/")

mask_id = 0
for task in ["CoLA", "SST-2", "MRPC", "STS-B", "QQP", "MNLI", "QNLI", "RTE"]:
    for seed in ["seed_1337", "seed_42", "seed_86", "seed_71", "seed_166"]:
        #Load Model
        model_path = f"../models/finetuned/{task}/{seed}/"
        tokenizer = BertTokenizer.from_pretrained(model_path)
        config = BertConfig.from_pretrained(model_path)
        config.output_attentions = True
        transformer_model = BertForSequenceClassification.from_pretrained('bert-base-uncased',  config=config)
        transformer_model = transformer_model.eval()
        transformer_model.cuda()
        args = Namespace(data_dir=f"../data/glue/{task}/", local_rank=-1, 
                         model_name_or_path=model_path, 
                         overwrite_cache=False, model_type="bert", max_seq_length=128)
        eval_dataset = load_and_cache_examples(args, task.lower(), tokenizer, evaluate=True)
        eval_sampler = RandomSampler(eval_dataset)
        eval_dataloader = DataLoader(eval_dataset, sampler=eval_sampler, batch_size=1)

        k = 0
        print(task, seed)
        for batch in eval_dataloader:
            batch = tuple(t.to("cuda:0") for t in batch)
            input_data =  {"input_ids": batch[0], "attention_mask": batch[1], "labels": batch[3]}
            n_tokens = batch[1].sum()
            if n_tokens < 16:
                continue
            subwords = tokenizer.convert_ids_to_tokens([int(t.item()) for t in batch[0][0]][:n_tokens])
            with torch.no_grad():
                _, _, _, allalpha_f, _ = transformer_model(**input_data)
                head_attentions = None
                
                layer = random.choice(range(len(allalpha_f)))
                head = random.choice(range(allalpha_f[layer].size(1)))
                
                weight_normed_atttention = allalpha_f[layer][0,head].norm(dim=-1)
                print(layer, head, weight_normed_atttention.shape)
                attention = weight_normed_atttention[:n_tokens, :n_tokens].cpu().numpy()
                plot_matrix(attention, subwords, subwords, f"./heatmap_attention_mask/images/{task}_{seed}_{mask_id}.pdf")
                np.save(f"./heatmap_attention_mask/data/{task}_{seed}_{mask_id}.npy", attention)
                mask_id += 1
                del allalpha_f
            k += 1
            if k == 15:
                break
# Out:
# CoLA seed_1337
# 9 8 torch.Size([128, 128])
# 11 5 torch.Size([128, 128])
# 9 9 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 5 6 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# 4 6 torch.Size([128, 128])
# 11 3 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# 1 6 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 1 8 torch.Size([128, 128])
# 11 10 torch.Size([128, 128])
# 5 6 torch.Size([128, 128])
# 6 11 torch.Size([128, 128])
# CoLA seed_42
# 4 10 torch.Size([128, 128])
# 0 5 torch.Size([128, 128])
# 9 1 torch.Size([128, 128])
# 7 3 torch.Size([128, 128])
# 2 5 torch.Size([128, 128])
# 10 11 torch.Size([128, 128])
# 9 7 torch.Size([128, 128])
# 9 4 torch.Size([128, 128])
# 3 8 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 8 9 torch.Size([128, 128])
# 9 0 torch.Size([128, 128])
# 1 6 torch.Size([128, 128])
# 10 9 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# CoLA seed_86
# 0 10 torch.Size([128, 128])
# 3 3 torch.Size([128, 128])
# 1 4 torch.Size([128, 128])
# 3 7 torch.Size([128, 128])
# 11 9 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 9 5 torch.Size([128, 128])
# 6 9 torch.Size([128, 128])
# 3 8 torch.Size([128, 128])
# 0 8 torch.Size([128, 128])
# 11 10 torch.Size([128, 128])
# 4 3 torch.Size([128, 128])
# 9 2 torch.Size([128, 128])
# 8 8 torch.Size([128, 128])
# 8 2 torch.Size([128, 128])
# CoLA seed_71
# 10 0 torch.Size([128, 128])
# 11 7 torch.Size([128, 128])
# 11 11 torch.Size([128, 128])
# 9 7 torch.Size([128, 128])
# 0 8 torch.Size([128, 128])
# 7 8 torch.Size([128, 128])
# 10 11 torch.Size([128, 128])
# 5 11 torch.Size([128, 128])
# 8 9 torch.Size([128, 128])
# 10 4 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 0 2 torch.Size([128, 128])
# 5 1 torch.Size([128, 128])
# 3 7 torch.Size([128, 128])
# CoLA seed_166
# 8 4 torch.Size([128, 128])
# 0 8 torch.Size([128, 128])
# 2 6 torch.Size([128, 128])
# 5 9 torch.Size([128, 128])
# 11 0 torch.Size([128, 128])
# 6 4 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# 7 5 torch.Size([128, 128])
# 6 1 torch.Size([128, 128])
# 3 5 torch.Size([128, 128])
# 10 10 torch.Size([128, 128])
# 10 9 torch.Size([128, 128])
# 4 11 torch.Size([128, 128])
# 3 3 torch.Size([128, 128])
# SST-2 seed_1337
# 2 7 torch.Size([128, 128])
# 6 9 torch.Size([128, 128])
# 6 8 torch.Size([128, 128])
# 4 2 torch.Size([128, 128])
# 3 11 torch.Size([128, 128])
# 5 6 torch.Size([128, 128])
# 9 3 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 2 11 torch.Size([128, 128])
# 7 9 torch.Size([128, 128])
# 11 10 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 0 8 torch.Size([128, 128])
# 9 3 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# SST-2 seed_42
# 4 8 torch.Size([128, 128])
# 5 6 torch.Size([128, 128])
# 5 3 torch.Size([128, 128])
# 4 7 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 2 9 torch.Size([128, 128])
# 4 11 torch.Size([128, 128])
# 3 6 torch.Size([128, 128])
# 11 1 torch.Size([128, 128])
# 7 11 torch.Size([128, 128])
# 0 5 torch.Size([128, 128])
# 1 4 torch.Size([128, 128])
# 7 8 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# SST-2 seed_86
# 2 0 torch.Size([128, 128])
# 8 9 torch.Size([128, 128])
# 6 3 torch.Size([128, 128])
# 10 7 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 3 4 torch.Size([128, 128])
# 0 7 torch.Size([128, 128])
# 11 3 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 9 1 torch.Size([128, 128])
# 10 10 torch.Size([128, 128])
# 2 8 torch.Size([128, 128])
# 9 10 torch.Size([128, 128])
# 10 0 torch.Size([128, 128])
# SST-2 seed_71
# 10 8 torch.Size([128, 128])
# 7 4 torch.Size([128, 128])
# 0 2 torch.Size([128, 128])
# 2 7 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 11 9 torch.Size([128, 128])
# 7 7 torch.Size([128, 128])
# 11 11 torch.Size([128, 128])
# 0 2 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 3 3 torch.Size([128, 128])
# 10 0 torch.Size([128, 128])
# 11 10 torch.Size([128, 128])
# 7 7 torch.Size([128, 128])
# 11 6 torch.Size([128, 128])
# SST-2 seed_166
# 10 4 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 11 6 torch.Size([128, 128])
# 5 10 torch.Size([128, 128])
# 1 2 torch.Size([128, 128])
# 1 11 torch.Size([128, 128])
# 0 4 torch.Size([128, 128])
# 10 10 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 10 3 torch.Size([128, 128])
# 1 1 torch.Size([128, 128])
# 2 8 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 9 9 torch.Size([128, 128])
# 3 0 torch.Size([128, 128])
# MRPC seed_1337
# 6 3 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 7 7 torch.Size([128, 128])
# 11 3 torch.Size([128, 128])
# 1 1 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 10 2 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 0 0 torch.Size([128, 128])
# 10 3 torch.Size([128, 128])
# 0 8 torch.Size([128, 128])
# 8 1 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# MRPC seed_42
# 4 8 torch.Size([128, 128])
# 8 4 torch.Size([128, 128])
# 2 11 torch.Size([128, 128])
# 0 6 torch.Size([128, 128])
# 4 7 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# 0 9 torch.Size([128, 128])
# 0 1 torch.Size([128, 128])
# 0 5 torch.Size([128, 128])
# 6 9 torch.Size([128, 128])
# 6 6 torch.Size([128, 128])
# 7 2 torch.Size([128, 128])
# 0 7 torch.Size([128, 128])
# 10 2 torch.Size([128, 128])
# MRPC seed_86
# 3 1 torch.Size([128, 128])
# 6 3 torch.Size([128, 128])
# 1 8 torch.Size([128, 128])
# 10 8 torch.Size([128, 128])
# 2 6 torch.Size([128, 128])
# 3 9 torch.Size([128, 128])
# 1 3 torch.Size([128, 128])
# 8 2 torch.Size([128, 128])
# 6 0 torch.Size([128, 128])
# 6 8 torch.Size([128, 128])
# 8 4 torch.Size([128, 128])
# 1 11 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# 4 0 torch.Size([128, 128])
# 11 7 torch.Size([128, 128])
# MRPC seed_71
# 5 5 torch.Size([128, 128])
# 0 5 torch.Size([128, 128])
# 9 9 torch.Size([128, 128])
# 5 11 torch.Size([128, 128])
# 3 1 torch.Size([128, 128])
# 8 0 torch.Size([128, 128])
# 11 0 torch.Size([128, 128])
# 6 11 torch.Size([128, 128])
# 8 6 torch.Size([128, 128])
# 0 6 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 11 7 torch.Size([128, 128])
# 1 5 torch.Size([128, 128])
# MRPC seed_166
# 9 8 torch.Size([128, 128])
# 9 7 torch.Size([128, 128])
# 8 8 torch.Size([128, 128])
# 3 1 torch.Size([128, 128])
# 7 9 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# 11 5 torch.Size([128, 128])
# 0 2 torch.Size([128, 128])
# 2 1 torch.Size([128, 128])
# 3 9 torch.Size([128, 128])
# 6 2 torch.Size([128, 128])
# 2 3 torch.Size([128, 128])
# 10 4 torch.Size([128, 128])
# 6 7 torch.Size([128, 128])
# 5 1 torch.Size([128, 128])
# STS-B seed_1337
# 5 9 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 9 7 torch.Size([128, 128])
# 4 8 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 4 7 torch.Size([128, 128])
# 4 2 torch.Size([128, 128])
# 11 1 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 11 11 torch.Size([128, 128])
# 2 2 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# 0 0 torch.Size([128, 128])
# 3 5 torch.Size([128, 128])
# 1 4 torch.Size([128, 128])
# STS-B seed_42
# 3 10 torch.Size([128, 128])
# 1 11 torch.Size([128, 128])
# 8 6 torch.Size([128, 128])
# 9 8 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 11 6 torch.Size([128, 128])
# 1 3 torch.Size([128, 128])
# 2 11 torch.Size([128, 128])
# 5 11 torch.Size([128, 128])
# 3 11 torch.Size([128, 128])
# 8 10 torch.Size([128, 128])
# 0 11 torch.Size([128, 128])
# 3 1 torch.Size([128, 128])
# 4 8 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# STS-B seed_86
# 5 4 torch.Size([128, 128])
# 0 4 torch.Size([128, 128])
# 6 5 torch.Size([128, 128])
# 5 11 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 8 9 torch.Size([128, 128])
# 4 8 torch.Size([128, 128])
# 4 0 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 2 6 torch.Size([128, 128])
# 7 7 torch.Size([128, 128])
# 10 9 torch.Size([128, 128])
# 5 2 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 8 10 torch.Size([128, 128])
# STS-B seed_71
# 0 7 torch.Size([128, 128])
# 1 9 torch.Size([128, 128])
# 3 11 torch.Size([128, 128])
# 8 6 torch.Size([128, 128])
# 11 4 torch.Size([128, 128])
# 3 8 torch.Size([128, 128])
# 7 10 torch.Size([128, 128])
# 9 9 torch.Size([128, 128])
# 6 9 torch.Size([128, 128])
# 7 11 torch.Size([128, 128])
# 9 2 torch.Size([128, 128])
# 6 6 torch.Size([128, 128])
# 11 6 torch.Size([128, 128])
# 2 1 torch.Size([128, 128])
# 4 5 torch.Size([128, 128])
# STS-B seed_166
# 2 4 torch.Size([128, 128])
# 10 9 torch.Size([128, 128])
# 4 11 torch.Size([128, 128])
# 8 4 torch.Size([128, 128])
# 1 1 torch.Size([128, 128])
# 9 2 torch.Size([128, 128])
# 2 5 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 2 8 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 2 8 torch.Size([128, 128])
# 6 11 torch.Size([128, 128])
# 5 10 torch.Size([128, 128])
# 6 8 torch.Size([128, 128])
# 0 4 torch.Size([128, 128])
# QQP seed_1337
# 1 6 torch.Size([128, 128])
# 11 6 torch.Size([128, 128])
# 9 8 torch.Size([128, 128])
# 7 0 torch.Size([128, 128])
# 1 0 torch.Size([128, 128])
# 9 3 torch.Size([128, 128])
# 2 3 torch.Size([128, 128])
# 11 1 torch.Size([128, 128])
# 11 0 torch.Size([128, 128])
# 11 0 torch.Size([128, 128])
# 9 0 torch.Size([128, 128])
# 9 8 torch.Size([128, 128])
# 9 0 torch.Size([128, 128])
# 9 11 torch.Size([128, 128])
# 5 2 torch.Size([128, 128])
# QQP seed_42
# 9 5 torch.Size([128, 128])
# 3 4 torch.Size([128, 128])
# 9 11 torch.Size([128, 128])
# 4 5 torch.Size([128, 128])
# 4 9 torch.Size([128, 128])
# 6 5 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 0 8 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 1 6 torch.Size([128, 128])
# 6 6 torch.Size([128, 128])
# 3 7 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 3 0 torch.Size([128, 128])
# 11 11 torch.Size([128, 128])
# QQP seed_86
# 8 2 torch.Size([128, 128])
# 6 4 torch.Size([128, 128])
# 9 9 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 7 2 torch.Size([128, 128])
# 1 0 torch.Size([128, 128])
# 8 10 torch.Size([128, 128])
# 4 5 torch.Size([128, 128])
# 7 0 torch.Size([128, 128])
# 10 4 torch.Size([128, 128])
# 9 3 torch.Size([128, 128])
# 8 7 torch.Size([128, 128])
# 6 1 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 0 3 torch.Size([128, 128])
# QQP seed_71
# 8 9 torch.Size([128, 128])
# 4 9 torch.Size([128, 128])
# 7 4 torch.Size([128, 128])
# 7 2 torch.Size([128, 128])
# 8 10 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# 11 5 torch.Size([128, 128])
# 10 7 torch.Size([128, 128])
# 6 9 torch.Size([128, 128])
# 8 9 torch.Size([128, 128])
# 0 3 torch.Size([128, 128])
# 10 7 torch.Size([128, 128])
# 10 11 torch.Size([128, 128])
# 8 2 torch.Size([128, 128])
# 7 11 torch.Size([128, 128])
# QQP seed_166
# 4 4 torch.Size([128, 128])
# 9 2 torch.Size([128, 128])
# 7 8 torch.Size([128, 128])
# 4 6 torch.Size([128, 128])
# 8 7 torch.Size([128, 128])
# 9 8 torch.Size([128, 128])
# 8 6 torch.Size([128, 128])
# 6 0 torch.Size([128, 128])
# 2 5 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 5 1 torch.Size([128, 128])
# 8 3 torch.Size([128, 128])
# 3 5 torch.Size([128, 128])
# 4 2 torch.Size([128, 128])
# MNLI seed_1337
# 10 7 torch.Size([128, 128])
# 3 5 torch.Size([128, 128])
# 1 7 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 10 0 torch.Size([128, 128])
# 8 1 torch.Size([128, 128])
# 3 11 torch.Size([128, 128])
# 11 3 torch.Size([128, 128])
# 3 8 torch.Size([128, 128])
# 6 9 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 0 0 torch.Size([128, 128])
# 2 10 torch.Size([128, 128])
# 3 9 torch.Size([128, 128])
# MNLI seed_42
# 11 0 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 7 8 torch.Size([128, 128])
# 9 0 torch.Size([128, 128])
# 3 1 torch.Size([128, 128])
# 8 5 torch.Size([128, 128])
# 8 2 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 8 4 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 7 4 torch.Size([128, 128])
# 1 7 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 0 0 torch.Size([128, 128])
# 3 11 torch.Size([128, 128])
# MNLI seed_86
# 4 11 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 10 2 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 1 8 torch.Size([128, 128])
# 2 5 torch.Size([128, 128])
# 11 10 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 2 10 torch.Size([128, 128])
# 4 8 torch.Size([128, 128])
# 6 4 torch.Size([128, 128])
# 6 0 torch.Size([128, 128])
# 6 11 torch.Size([128, 128])
# 3 4 torch.Size([128, 128])
# MNLI seed_71
# 7 4 torch.Size([128, 128])
# 11 4 torch.Size([128, 128])
# 11 6 torch.Size([128, 128])
# 1 9 torch.Size([128, 128])
# 8 8 torch.Size([128, 128])
# 4 2 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 8 5 torch.Size([128, 128])
# 7 7 torch.Size([128, 128])
# 2 6 torch.Size([128, 128])
# 11 4 torch.Size([128, 128])
# 7 10 torch.Size([128, 128])
# 10 9 torch.Size([128, 128])
# 2 8 torch.Size([128, 128])
# 4 5 torch.Size([128, 128])
# MNLI seed_166
# 0 10 torch.Size([128, 128])
# 9 9 torch.Size([128, 128])
# 5 7 torch.Size([128, 128])
# 1 4 torch.Size([128, 128])
# 8 9 torch.Size([128, 128])
# 2 4 torch.Size([128, 128])
# 4 2 torch.Size([128, 128])
# 4 6 torch.Size([128, 128])
# 11 8 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# 3 5 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 9 0 torch.Size([128, 128])
# 5 7 torch.Size([128, 128])
# QNLI seed_1337
# 3 10 torch.Size([128, 128])
# 8 5 torch.Size([128, 128])
# 10 7 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 11 3 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 3 2 torch.Size([128, 128])
# 10 4 torch.Size([128, 128])
# 10 8 torch.Size([128, 128])
# 7 10 torch.Size([128, 128])
# 6 10 torch.Size([128, 128])
# 0 4 torch.Size([128, 128])
# 10 4 torch.Size([128, 128])
# 10 5 torch.Size([128, 128])
# QNLI seed_42
# 0 2 torch.Size([128, 128])
# 8 5 torch.Size([128, 128])
# 1 5 torch.Size([128, 128])
# 11 0 torch.Size([128, 128])
# 10 2 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 8 3 torch.Size([128, 128])
# 7 3 torch.Size([128, 128])
# 11 8 torch.Size([128, 128])
# 5 6 torch.Size([128, 128])
# 2 3 torch.Size([128, 128])
# 3 3 torch.Size([128, 128])
# 0 9 torch.Size([128, 128])
# 8 5 torch.Size([128, 128])
# 2 9 torch.Size([128, 128])
# QNLI seed_86
# 7 5 torch.Size([128, 128])
# 1 11 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 9 4 torch.Size([128, 128])
# 6 0 torch.Size([128, 128])
# 7 4 torch.Size([128, 128])
# 7 6 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 10 3 torch.Size([128, 128])
# 11 2 torch.Size([128, 128])
# 7 4 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 8 0 torch.Size([128, 128])
# 7 5 torch.Size([128, 128])
# 6 11 torch.Size([128, 128])
# QNLI seed_71
# 11 6 torch.Size([128, 128])
# 5 7 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 7 11 torch.Size([128, 128])
# 4 1 torch.Size([128, 128])
# 7 5 torch.Size([128, 128])
# 8 5 torch.Size([128, 128])
# 0 3 torch.Size([128, 128])
# 7 6 torch.Size([128, 128])
# 1 8 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 1 1 torch.Size([128, 128])
# 9 3 torch.Size([128, 128])
# 7 6 torch.Size([128, 128])
# 11 7 torch.Size([128, 128])
# QNLI seed_166
# 5 3 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 8 1 torch.Size([128, 128])
# 5 7 torch.Size([128, 128])
# 3 9 torch.Size([128, 128])
# 0 0 torch.Size([128, 128])
# 2 1 torch.Size([128, 128])
# 5 3 torch.Size([128, 128])
# 9 10 torch.Size([128, 128])
# 4 8 torch.Size([128, 128])
# 5 10 torch.Size([128, 128])
# 4 8 torch.Size([128, 128])
# 6 8 torch.Size([128, 128])
# 2 8 torch.Size([128, 128])
# 2 4 torch.Size([128, 128])
# RTE seed_1337
# 0 3 torch.Size([128, 128])
# 6 8 torch.Size([128, 128])
# 4 0 torch.Size([128, 128])
# 11 1 torch.Size([128, 128])
# 7 6 torch.Size([128, 128])
# 3 5 torch.Size([128, 128])
# 8 10 torch.Size([128, 128])
# 8 6 torch.Size([128, 128])
# 11 5 torch.Size([128, 128])
# 3 8 torch.Size([128, 128])
# 5 3 torch.Size([128, 128])
# 1 11 torch.Size([128, 128])
# 2 3 torch.Size([128, 128])
# 5 8 torch.Size([128, 128])
# 1 8 torch.Size([128, 128])
# RTE seed_42
# 1 6 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 2 2 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 3 3 torch.Size([128, 128])
# 6 11 torch.Size([128, 128])
# 3 10 torch.Size([128, 128])
# 10 6 torch.Size([128, 128])
# 1 3 torch.Size([128, 128])
# 8 3 torch.Size([128, 128])
# 3 9 torch.Size([128, 128])
# 5 11 torch.Size([128, 128])
# 5 4 torch.Size([128, 128])
# 3 10 torch.Size([128, 128])
# 7 5 torch.Size([128, 128])
# RTE seed_86
# 1 0 torch.Size([128, 128])
# 1 6 torch.Size([128, 128])
# 11 7 torch.Size([128, 128])
# 1 10 torch.Size([128, 128])
# 10 0 torch.Size([128, 128])
# 8 1 torch.Size([128, 128])
# 10 8 torch.Size([128, 128])
# 5 11 torch.Size([128, 128])
# 2 10 torch.Size([128, 128])
# 7 8 torch.Size([128, 128])
# 7 6 torch.Size([128, 128])
# 11 4 torch.Size([128, 128])
# 0 10 torch.Size([128, 128])
# 0 3 torch.Size([128, 128])
# 5 3 torch.Size([128, 128])
# RTE seed_71
# 5 11 torch.Size([128, 128])
# 9 0 torch.Size([128, 128])
# 7 2 torch.Size([128, 128])
# 3 4 torch.Size([128, 128])
# 1 2 torch.Size([128, 128])
# 4 2 torch.Size([128, 128])
# 6 4 torch.Size([128, 128])
# 6 7 torch.Size([128, 128])
# 5 0 torch.Size([128, 128])
# 1 11 torch.Size([128, 128])
# 2 3 torch.Size([128, 128])
# 0 3 torch.Size([128, 128])
# 6 0 torch.Size([128, 128])
# 3 11 torch.Size([128, 128])
# 2 11 torch.Size([128, 128])
# RTE seed_166
# 4 8 torch.Size([128, 128])
# 2 10 torch.Size([128, 128])
# 3 4 torch.Size([128, 128])
# 7 3 torch.Size([128, 128])
# 8 0 torch.Size([128, 128])
# 4 5 torch.Size([128, 128])
# 7 11 torch.Size([128, 128])
# 10 7 torch.Size([128, 128])
# 0 9 torch.Size([128, 128])
# 9 6 torch.Size([128, 128])
# 7 5 torch.Size([128, 128])
# 11 1 torch.Size([128, 128])
# 4 4 torch.Size([128, 128])
# 10 1 torch.Size([128, 128])
# 1 4 torch.Size([128, 128])

# %%
# !mkdir heatmap_attention_mask/images heatmap_attention_mask/data

# %%
# !mv heatmap_attention_mask/*.npy heatmap_attention_mask/data

# %%
# !mv heatmap_attention_mask/*.pdf heatmap_attention_mask/images

# %%
# !touch heatmap_attention_mask/images/labels.txt
