# %%
# %matplotlib inline

# %%
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import time
import json
import itertools
from statsmodels.stats.contingency_tables import cochrans_q
from statsmodels.stats.inter_rater import fleiss_kappa
import krippendorff

# %%
def load_head_data(experiments_path):
    head_data = {}
    for task_dir in experiments_path.iterdir():
        head_data[task_dir.stem] = {}
        for seed_dir in task_dir.iterdir():
            head_mask = np.load(seed_dir / "head_mask.npy")
            head_data[task_dir.stem][seed_dir.stem] = {
                "head_mask": head_mask,
            }
    return head_data
def load_mlp_data(experiments_path):
    mlp_data = {}
    for task_dir in experiments_path.iterdir():
        mlp_data[task_dir.stem] = {}
        for seed_dir in task_dir.iterdir():
            mlp_mask = np.load(seed_dir / "mlp_mask.npy")
            mlp_importance = np.load(seed_dir / "mlp_importance.npy")
            mlp_data[task_dir.stem][seed_dir.stem] = {
                "mlp_mask": mlp_mask,
                "mlp_importance": mlp_importance
            }
    return mlp_data

# %%
experiments_path = pathlib.Path("../masks/heads_mlps")
heads = load_head_data(experiments_path)

experiments_path = pathlib.Path("../masks/heads_mlps_hans")
hans_heads = load_head_data(experiments_path)

for k, v in hans_heads.items():
    heads[k] = v

experiments_path = pathlib.Path("../masks/heads_mlps")
mlps = load_mlp_data(experiments_path)




experiments_path = pathlib.Path("../masks/heads_mlps_hans")
hans_mlps = load_mlp_data(experiments_path)

for k, v in hans_mlps.items():
    mlps[k] = v

# %%
def cochrans_q_masks(masks):
    inp = np.array(masks).transpose()
    return cochrans_q(inp)



def krippendorff_alpha_tasks_separate(data, mask="head_mask"):
    for task in sorted(data.keys()):
        krippendorff_alpha_tasks(data, [task], mask)     
        
def krippendorff_alpha_tasks(data, tasks, mask="head_mask"):
    masks = []
    seeds = sorted(data[tasks[0]].keys())
    for task in tasks:
        for seed in seeds:
            masks.append(data[task][seed][mask].reshape(-1))
    alpha = krippendorff.alpha(masks)
    print(','.join(tasks))
    print("---------")
    print(f'alpha: {alpha}')

    
def fleiss_kappa_tasks_separate(data, mask="head_mask"):
    for task in sorted(data.keys()):
        fleiss_kappa_tasks(data, [task], mask)     
        
def fleiss_kappa_tasks(data, tasks, mask="head_mask"):
    masks = []
    
    good_mask_sum = np.zeros_like(data["MNLI"]["seed_42"][mask].reshape(-1))
    bad_mask_sum =  np.zeros_like(data["MNLI"]["seed_42"][mask].reshape(-1))
    seeds = sorted(data[tasks[0]].keys())
    for task in tasks:
        for seed in seeds:
            good_mask_sum = good_mask_sum + data[task][seed][mask].reshape(-1)
            bad_mask_sum = bad_mask_sum + (1 - data[task][seed][mask].reshape(-1))
    table = np.array([good_mask_sum, bad_mask_sum]).transpose()
    kappa = fleiss_kappa(table)
    print(','.join(tasks))
    print("---------")
    print(f'Feliss Kappa: {kappa}')    

def print_p_value_tasks_separate(data, mask="head_mask"):
    for task in sorted(data.keys()):
        print_p_value_tasks(data, [task], mask)        
        
def print_p_value_tasks(data, tasks, mask="head_mask"):
    masks = []
    seeds = sorted(data[tasks[0]].keys())
    for task in tasks:
        for seed in seeds:
            masks.append(data[task][seed][mask].reshape(-1))
    test_result = cochrans_q_masks(masks)
    print(','.join(tasks))
    print("---------------------------------------------------------------------")
    print(f'p-value: {test_result.pvalue}')
    print(f"{'Null hypothesis (all seeds are similar) is rejected.' if test_result.pvalue < 0.05 else 'Null hypothesis (all seeds are similar) is not rejected.'}")
    
    if len(tasks) == 1:
        masks_combos = list(itertools.combinations(range(len(masks)), 2))
    else:
        masks_combos = []
        for i in range(len(seeds)):
            for j in range(len(seeds)):
                if i < j:
                    mask_1_idx = i
                    mask_2_idx = len(seeds)  +  j
                    masks_combos.append((mask_1_idx, mask_2_idx))
    similar_masks_combos = []
    for mask_1, mask_2 in masks_combos:
        r = cochrans_q_masks([masks[mask_1], masks[mask_2]])
        if r.pvalue >= 0.05:
            task1_name, seed1_name = tasks[mask_1 // len(seeds)], seeds[mask_1 % len(seeds)]
            task2_name, seed2_name = tasks[mask_2 // len(seeds)], seeds[mask_2 % len(seeds)]
            similar_masks_combos.append((f"{task1_name}-{seed1_name}", f"{task2_name}-{seed2_name}"))
    
    print(f"Total mask pairs where Null hypothesis is not rejected - {len(similar_masks_combos)}")
    print(f"Total mask pairs - {len(masks_combos)}")
    print(f"Percentage - {len(similar_masks_combos)/ len(masks_combos)}")
    print("\nSimilar Mask Pairs:\n")
    print("\t".join([",".join(p) for p in similar_masks_combos]))
    print("\n\n")

# %% [markdown]
# # Seeds in a Task

# %% [markdown]
# ## Heads

# %%
print_p_value_tasks_separate(heads)
# Out:
# CoLA
# ---------------------------------------------------------------------
# p-value: 2.113894110905964e-11
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,CoLA-seed_42	CoLA-seed_1337,CoLA-seed_71	CoLA-seed_166,CoLA-seed_42
#
#
#
# HANS
# ---------------------------------------------------------------------
# p-value: 0.004749695087342902
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# HANS-seed_1337,HANS-seed_42	HANS-seed_1337,HANS-seed_71	HANS-seed_1337,HANS-seed_86	HANS-seed_166,HANS-seed_86	HANS-seed_42,HANS-seed_71	HANS-seed_42,HANS-seed_86	HANS-seed_71,HANS-seed_86
#
#
#
# HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 1.0701419296602784e-05
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,HANS_MNLI-seed_42	HANS_MNLI-seed_1337,HANS_MNLI-seed_86	HANS_MNLI-seed_166,HANS_MNLI-seed_42	HANS_MNLI-seed_71,HANS_MNLI-seed_86
#
#
#
# MNLI
# ---------------------------------------------------------------------
# p-value: 0.39484537126862373
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI-seed_166	MNLI-seed_1337,MNLI-seed_42	MNLI-seed_1337,MNLI-seed_71	MNLI-seed_1337,MNLI-seed_86	MNLI-seed_166,MNLI-seed_42	MNLI-seed_166,MNLI-seed_71	MNLI-seed_166,MNLI-seed_86	MNLI-seed_42,MNLI-seed_86	MNLI-seed_71,MNLI-seed_86
#
#
#
# MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.04886971480018394
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MNLI_TWO-seed_42	MNLI_TWO-seed_1337,MNLI_TWO-seed_71	MNLI_TWO-seed_1337,MNLI_TWO-seed_86	MNLI_TWO-seed_166,MNLI_TWO-seed_42	MNLI_TWO-seed_166,MNLI_TWO-seed_86	MNLI_TWO-seed_42,MNLI_TWO-seed_71	MNLI_TWO-seed_42,MNLI_TWO-seed_86	MNLI_TWO-seed_71,MNLI_TWO-seed_86
#
#
#
# MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.10751157701176865
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_166	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MRPC
# ---------------------------------------------------------------------
# p-value: 0.013837912255726509
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,MRPC-seed_166	MRPC-seed_1337,MRPC-seed_42	MRPC-seed_1337,MRPC-seed_71	MRPC-seed_1337,MRPC-seed_86	MRPC-seed_166,MRPC-seed_86	MRPC-seed_42,MRPC-seed_71	MRPC-seed_71,MRPC-seed_86
#
#
#
# QNLI
# ---------------------------------------------------------------------
# p-value: 0.0329959709332481
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,QNLI-seed_166	QNLI-seed_1337,QNLI-seed_71	QNLI-seed_1337,QNLI-seed_86	QNLI-seed_166,QNLI-seed_42	QNLI-seed_166,QNLI-seed_86	QNLI-seed_42,QNLI-seed_86
#
#
#
# QQP
# ---------------------------------------------------------------------
# p-value: 2.970583205868185e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# QQP-seed_1337,QQP-seed_166	QQP-seed_1337,QQP-seed_42	QQP-seed_166,QQP-seed_42	QQP-seed_71,QQP-seed_86
#
#
#
# RTE
# ---------------------------------------------------------------------
# p-value: 2.6922221869717934e-36
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 2
# Total mask pairs - 10
# Percentage - 0.2
#
# Similar Mask Pairs:
#
# RTE-seed_166,RTE-seed_71	RTE-seed_71,RTE-seed_86
#
#
#
# SST-2
# ---------------------------------------------------------------------
# p-value: 3.417832305517236e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 2
# Total mask pairs - 10
# Percentage - 0.2
#
# Similar Mask Pairs:
#
# SST-2-seed_42,SST-2-seed_86	SST-2-seed_71,SST-2-seed_86
#
#
#
# STS-B
# ---------------------------------------------------------------------
# p-value: 0.05786884035446416
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# STS-B-seed_1337,STS-B-seed_166	STS-B-seed_1337,STS-B-seed_42	STS-B-seed_1337,STS-B-seed_71	STS-B-seed_1337,STS-B-seed_86	STS-B-seed_166,STS-B-seed_42	STS-B-seed_166,STS-B-seed_86	STS-B-seed_42,STS-B-seed_71	STS-B-seed_42,STS-B-seed_86	STS-B-seed_71,STS-B-seed_86
#
#
#
# WNLI
# ---------------------------------------------------------------------
# p-value: 2.42151439227382e-123
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
# /home/sai/miniconda3/envs/bertexp/lib/python3.7/site-packages/statsmodels/stats/contingency_tables.py:1411: RuntimeWarning: invalid value encountered in double_scalars
#   / (k * count_row_ss - np.sum(count_row_success**2)))

# %%
krippendorff_alpha_tasks_separate(heads)
# Out:
# CoLA
# ---------
# alpha: 0.22920627475942013
# HANS
# ---------
# alpha: 0.1511915220733583
# HANS_MNLI
# ---------
# alpha: 0.28187521458222786
# MNLI
# ---------
# alpha: 0.25860365198711066
# MNLI_TWO
# ---------
# alpha: 0.2586712903250721
# MNLI_TWO_HALF
# ---------
# alpha: 0.27296884185773074
# MRPC
# ---------
# alpha: 0.21637124992829693
# QNLI
# ---------
# alpha: 0.30249353262431733
# QQP
# ---------
# alpha: 0.1923483546980309
# RTE
# ---------
# alpha: 0.1810617760617761
# SST-2
# ---------
# alpha: 0.32545842217484
# STS-B
# ---------
# alpha: 0.2226213727678572
# WNLI
# ---------
# alpha: -0.24826388888888884

# %%
fleiss_kappa_tasks_separate(heads)
# Out:
# CoLA
# ---------
# Feliss Kappa: 0.22813420962464326
# HANS
# ---------
# Feliss Kappa: 0.15001104022155096
# HANS_MNLI
# ---------
# Feliss Kappa: 0.28087644551473623
# MNLI
# ---------
# Feliss Kappa: 0.2575725895259203
# MNLI_TWO
# ---------
# Feliss Kappa: 0.257640223291972
# MNLI_TWO_HALF
# ---------
# Feliss Kappa: 0.2719576396639385
# MRPC
# ---------
# Feliss Kappa: 0.21528139476292904
# QNLI
# ---------
# Feliss Kappa: 0.30152363649730873
# QQP
# ---------
# Feliss Kappa: 0.19122512161909952
# RTE
# ---------
# Feliss Kappa: 0.1799227762377962
# SST-2
# ---------
# Feliss Kappa: 0.32452024723070516
# STS-B
# ---------
# Feliss Kappa: 0.22154005502120921
# WNLI
# ---------
# Feliss Kappa: -0.25000037252910756

# %% [markdown]
# ## MLPs

# %%
print_p_value_tasks_separate(mlps, mask="mlp_mask")
# Out:
# CoLA
# ---------------------------------------------------------------------
# p-value: 0.3232398928813502
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,CoLA-seed_166	CoLA-seed_1337,CoLA-seed_42	CoLA-seed_1337,CoLA-seed_86	CoLA-seed_166,CoLA-seed_42	CoLA-seed_166,CoLA-seed_71	CoLA-seed_166,CoLA-seed_86	CoLA-seed_42,CoLA-seed_71	CoLA-seed_42,CoLA-seed_86	CoLA-seed_71,CoLA-seed_86
#
#
#
# HANS
# ---------------------------------------------------------------------
# p-value: 0.9594907270068882
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,HANS-seed_166	HANS-seed_1337,HANS-seed_42	HANS-seed_1337,HANS-seed_71	HANS-seed_1337,HANS-seed_86	HANS-seed_166,HANS-seed_42	HANS-seed_166,HANS-seed_71	HANS-seed_166,HANS-seed_86	HANS-seed_42,HANS-seed_71	HANS-seed_42,HANS-seed_86	HANS-seed_71,HANS-seed_86
#
#
#
# HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 0.9786790480094321
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,HANS_MNLI-seed_166	HANS_MNLI-seed_1337,HANS_MNLI-seed_42	HANS_MNLI-seed_1337,HANS_MNLI-seed_71	HANS_MNLI-seed_1337,HANS_MNLI-seed_86	HANS_MNLI-seed_166,HANS_MNLI-seed_42	HANS_MNLI-seed_166,HANS_MNLI-seed_71	HANS_MNLI-seed_166,HANS_MNLI-seed_86	HANS_MNLI-seed_42,HANS_MNLI-seed_71	HANS_MNLI-seed_42,HANS_MNLI-seed_86	HANS_MNLI-seed_71,HANS_MNLI-seed_86
#
#
#
# MNLI
# ---------------------------------------------------------------------
# p-value: 0.8224157057672481
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI-seed_166	MNLI-seed_1337,MNLI-seed_42	MNLI-seed_1337,MNLI-seed_71	MNLI-seed_1337,MNLI-seed_86	MNLI-seed_166,MNLI-seed_42	MNLI-seed_166,MNLI-seed_71	MNLI-seed_166,MNLI-seed_86	MNLI-seed_42,MNLI-seed_71	MNLI-seed_42,MNLI-seed_86	MNLI-seed_71,MNLI-seed_86
#
#
#
# MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.8312925312037189
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MNLI_TWO-seed_166	MNLI_TWO-seed_1337,MNLI_TWO-seed_42	MNLI_TWO-seed_1337,MNLI_TWO-seed_71	MNLI_TWO-seed_1337,MNLI_TWO-seed_86	MNLI_TWO-seed_166,MNLI_TWO-seed_42	MNLI_TWO-seed_166,MNLI_TWO-seed_71	MNLI_TWO-seed_166,MNLI_TWO-seed_86	MNLI_TWO-seed_42,MNLI_TWO-seed_71	MNLI_TWO-seed_42,MNLI_TWO-seed_86	MNLI_TWO-seed_71,MNLI_TWO-seed_86
#
#
#
# MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.5249309467861041
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_166	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_42,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_42,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MRPC
# ---------------------------------------------------------------------
# p-value: 0.6833711942656508
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,MRPC-seed_166	MRPC-seed_1337,MRPC-seed_42	MRPC-seed_1337,MRPC-seed_71	MRPC-seed_1337,MRPC-seed_86	MRPC-seed_166,MRPC-seed_71	MRPC-seed_166,MRPC-seed_86	MRPC-seed_42,MRPC-seed_71	MRPC-seed_42,MRPC-seed_86	MRPC-seed_71,MRPC-seed_86
#
#
#
# QNLI
# ---------------------------------------------------------------------
# p-value: 0.9824769036935782
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,QNLI-seed_166	QNLI-seed_1337,QNLI-seed_42	QNLI-seed_1337,QNLI-seed_71	QNLI-seed_1337,QNLI-seed_86	QNLI-seed_166,QNLI-seed_42	QNLI-seed_166,QNLI-seed_71	QNLI-seed_166,QNLI-seed_86	QNLI-seed_42,QNLI-seed_71	QNLI-seed_42,QNLI-seed_86	QNLI-seed_71,QNLI-seed_86
#
#
#
# QQP
# ---------------------------------------------------------------------
# p-value: 0.9735009788392561
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QQP-seed_1337,QQP-seed_166	QQP-seed_1337,QQP-seed_42	QQP-seed_1337,QQP-seed_71	QQP-seed_1337,QQP-seed_86	QQP-seed_166,QQP-seed_42	QQP-seed_166,QQP-seed_71	QQP-seed_166,QQP-seed_86	QQP-seed_42,QQP-seed_71	QQP-seed_42,QQP-seed_86	QQP-seed_71,QQP-seed_86
#
#
#
# RTE
# ---------------------------------------------------------------------
# p-value: 0.25477265448360564
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# RTE-seed_1337,RTE-seed_166	RTE-seed_1337,RTE-seed_42	RTE-seed_1337,RTE-seed_71	RTE-seed_166,RTE-seed_42	RTE-seed_166,RTE-seed_71	RTE-seed_166,RTE-seed_86	RTE-seed_42,RTE-seed_71	RTE-seed_42,RTE-seed_86	RTE-seed_71,RTE-seed_86
#
#
#
# SST-2
# ---------------------------------------------------------------------
# p-value: 0.8979161202208832
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# SST-2-seed_1337,SST-2-seed_166	SST-2-seed_1337,SST-2-seed_42	SST-2-seed_1337,SST-2-seed_71	SST-2-seed_1337,SST-2-seed_86	SST-2-seed_166,SST-2-seed_42	SST-2-seed_166,SST-2-seed_71	SST-2-seed_166,SST-2-seed_86	SST-2-seed_42,SST-2-seed_71	SST-2-seed_42,SST-2-seed_86	SST-2-seed_71,SST-2-seed_86
#
#
#
# STS-B
# ---------------------------------------------------------------------
# p-value: 0.47205433276263287
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# STS-B-seed_1337,STS-B-seed_166	STS-B-seed_1337,STS-B-seed_42	STS-B-seed_1337,STS-B-seed_71	STS-B-seed_1337,STS-B-seed_86	STS-B-seed_166,STS-B-seed_42	STS-B-seed_166,STS-B-seed_71	STS-B-seed_166,STS-B-seed_86	STS-B-seed_42,STS-B-seed_71	STS-B-seed_42,STS-B-seed_86	STS-B-seed_71,STS-B-seed_86
#
#
#
# WNLI
# ---------------------------------------------------------------------
# p-value: nan
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:

# %%
krippendorff_alpha_tasks_separate(mlps, mask="mlp_mask")
# Out:
# CoLA
# ---------
# alpha: 0.4537037037037036
# HANS
# ---------
# alpha: 0.3413631022326674
# HANS_MNLI
# ---------
# alpha: 0.31835686777920413
# MNLI
# ---------
# alpha: 0.18055555555555558
# MNLI_TWO
# ---------
# alpha: 0.2804878048780487
# MNLI_TWO_HALF
# ---------
# alpha: 0.4319640564826701
# MRPC
# ---------
# alpha: 0.03804347826086951
# QNLI
# ---------
# alpha: 0.16193181818181823
# QQP
# ---------
# alpha: 0.03146374829001364
# RTE
# ---------
# alpha: -0.0993788819875776
# SST-2
# ---------
# alpha: 0.06349206349206349
# STS-B
# ---------
# alpha: 0.09870740305522918
# WNLI
# ---------
# alpha: nan

# %% [markdown]
# ## Pairwise Task to task comparison

# %% [markdown]
# # Heads

# %%
tasks = sorted(heads.keys())
for t1, t2 in itertools.combinations(tasks, 2):
    print_p_value_tasks(heads, [t1, t2])

# %%
tasks = sorted(heads.keys())
for t1, t2 in itertools.combinations(tasks, 2):
    krippendorff_alpha_tasks(heads, [t1, t2])
# Out:
# CoLA,HANS
# ---------
# alpha: 0.12605966529226342
# CoLA,HANS_MNLI
# ---------
# alpha: 0.15390838813984287
# CoLA,MNLI
# ---------
# alpha: 0.1472484134521177
# CoLA,MNLI_TWO
# ---------
# alpha: 0.14212075685326764
# CoLA,MNLI_TWO_HALF
# ---------
# alpha: 0.14118472263574544
# CoLA,MRPC
# ---------
# alpha: 0.13809026972718175
# CoLA,QNLI
# ---------
# alpha: 0.17694109929350343
# CoLA,QQP
# ---------
# alpha: 0.1261541914627099
# CoLA,RTE
# ---------
# alpha: 0.135281470108642
# CoLA,SST-2
# ---------
# alpha: 0.19279541253541732
# CoLA,STS-B
# ---------
# alpha: 0.14422753716871406
# CoLA,WNLI
# ---------
# alpha: -0.009957825396038844
# HANS,HANS_MNLI
# ---------
# alpha: 0.17639652014652096
# HANS,MNLI
# ---------
# alpha: 0.15112170220719234
# HANS,MNLI_TWO
# ---------
# alpha: 0.1591999239058064
# HANS,MNLI_TWO_HALF
# ---------
# alpha: 0.16878590515113767
# HANS,MRPC
# ---------
# alpha: 0.14627980692708387
# HANS,QNLI
# ---------
# alpha: 0.1579596739596747
# HANS,QQP
# ---------
# alpha: 0.1233765941364734
# HANS,RTE
# ---------
# alpha: 0.14104061594315065
# HANS,SST-2
# ---------
# alpha: 0.17432937876915733
# HANS,STS-B
# ---------
# alpha: 0.1442396064226641
# HANS,WNLI
# ---------
# alpha: -0.009623983769964761
# HANS_MNLI,MNLI
# ---------
# alpha: 0.21410759656909628
# HANS_MNLI,MNLI_TWO
# ---------
# alpha: 0.24977425602146752
# HANS_MNLI,MNLI_TWO_HALF
# ---------
# alpha: 0.24511561497862921
# HANS_MNLI,MRPC
# ---------
# alpha: 0.18620522765319203
# HANS_MNLI,QNLI
# ---------
# alpha: 0.22258034575995778
# HANS_MNLI,QQP
# ---------
# alpha: 0.18723093673009883
# HANS_MNLI,RTE
# ---------
# alpha: 0.1598100611772495
# HANS_MNLI,SST-2
# ---------
# alpha: 0.17962345835051297
# HANS_MNLI,STS-B
# ---------
# alpha: 0.16102426169357742
# HANS_MNLI,WNLI
# ---------
# alpha: 0.013826452295703784
# MNLI,MNLI_TWO
# ---------
# alpha: 0.24148033735412422
# MNLI,MNLI_TWO_HALF
# ---------
# alpha: 0.260903228715729
# MNLI,MRPC
# ---------
# alpha: 0.2018879741222478
# MNLI,QNLI
# ---------
# alpha: 0.22794618133130917
# MNLI,QQP
# ---------
# alpha: 0.15662409840858604
# MNLI,RTE
# ---------
# alpha: 0.16903253609136015
# MNLI,SST-2
# ---------
# alpha: 0.1866126679295409
# MNLI,STS-B
# ---------
# alpha: 0.169926782911902
# MNLI,WNLI
# ---------
# alpha: -0.007094333781319628
# MNLI_TWO,MNLI_TWO_HALF
# ---------
# alpha: 0.26306518565491166
# MNLI_TWO,MRPC
# ---------
# alpha: 0.19965727533457556
# MNLI_TWO,QNLI
# ---------
# alpha: 0.24891389764734473
# MNLI_TWO,QQP
# ---------
# alpha: 0.18882625482625526
# MNLI_TWO,RTE
# ---------
# alpha: 0.18112303457375523
# MNLI_TWO,SST-2
# ---------
# alpha: 0.18432870585242334
# MNLI_TWO,STS-B
# ---------
# alpha: 0.19134753077724498
# MNLI_TWO,WNLI
# ---------
# alpha: 0.014716413456108524
# MNLI_TWO_HALF,MRPC
# ---------
# alpha: 0.22509217562872863
# MNLI_TWO_HALF,QNLI
# ---------
# alpha: 0.27745294926505826
# MNLI_TWO_HALF,QQP
# ---------
# alpha: 0.19279541253541754
# MNLI_TWO_HALF,RTE
# ---------
# alpha: 0.21044439054625852
# MNLI_TWO_HALF,SST-2
# ---------
# alpha: 0.17277563277563313
# MNLI_TWO_HALF,STS-B
# ---------
# alpha: 0.18598579071206778
# MNLI_TWO_HALF,WNLI
# ---------
# alpha: 0.010580063605767687
# MRPC,QNLI
# ---------
# alpha: 0.2160456789450047
# MRPC,QQP
# ---------
# alpha: 0.1550365571845289
# MRPC,RTE
# ---------
# alpha: 0.17729586574222367
# MRPC,SST-2
# ---------
# alpha: 0.14113742937816565
# MRPC,STS-B
# ---------
# alpha: 0.20541939982580726
# MRPC,WNLI
# ---------
# alpha: -0.009823219690904494
# QNLI,QQP
# ---------
# alpha: 0.207452260125098
# QNLI,RTE
# ---------
# alpha: 0.20714294384274767
# QNLI,SST-2
# ---------
# alpha: 0.1388534623697263
# QNLI,STS-B
# ---------
# alpha: 0.1853593746597867
# QNLI,WNLI
# ---------
# alpha: 0.01338979632990589
# QQP,RTE
# ---------
# alpha: 0.1339025659981542
# QQP,SST-2
# ---------
# alpha: 0.13510883386106287
# QQP,STS-B
# ---------
# alpha: 0.16080631686743785
# QQP,WNLI
# ---------
# alpha: -0.006209416934876977
# RTE,SST-2
# ---------
# alpha: 0.14867864245777163
# RTE,STS-B
# ---------
# alpha: 0.19011358490598496
# RTE,WNLI
# ---------
# alpha: -0.006435594101887654
# SST-2,STS-B
# ---------
# alpha: 0.13794308159459434
# SST-2,WNLI
# ---------
# alpha: 0.03264789079843444
# STS-B,WNLI
# ---------
# alpha: 0.0018897860180763226

# %% [markdown]
# ## MLPs

# %%
for t1, t2 in itertools.combinations(tasks, 2):
    print_p_value_tasks(mlps, [t1, t2], mask="mlp_mask")

# %%
tasks = sorted(mlps.keys())
for t1, t2 in itertools.combinations(tasks, 2):
    krippendorff_alpha_tasks(mlps, [t1, t2], mask="mlp_mask")
# Out:
# CoLA,HANS
# ---------
# alpha: 0.22340111995284406
# CoLA,HANS_MNLI
# ---------
# alpha: 0.21501754385964922
# CoLA,MNLI
# ---------
# alpha: 0.2309992283950617
# CoLA,MNLI_TWO
# ---------
# alpha: 0.23728654970760243
# CoLA,MNLI_TWO_HALF
# ---------
# alpha: 0.17047953216374256
# CoLA,MRPC
# ---------
# alpha: 0.16700000000000004
# CoLA,QNLI
# ---------
# alpha: 0.11688311688311681
# CoLA,QQP
# ---------
# alpha: 0.1050849145873799
# CoLA,RTE
# ---------
# alpha: 0.07444444444444442
# CoLA,SST-2
# ---------
# alpha: 0.046904730297800845
# CoLA,STS-B
# ---------
# alpha: 0.1933392278219862
# CoLA,WNLI
# ---------
# alpha: -0.046202768424990825
# HANS,HANS_MNLI
# ---------
# alpha: 0.29772079772079785
# HANS,MNLI
# ---------
# alpha: 0.13049295049912513
# HANS,MNLI_TWO
# ---------
# alpha: 0.2573599240265908
# HANS,MNLI_TWO_HALF
# ---------
# alpha: 0.26543209876543206
# HANS,MRPC
# ---------
# alpha: 0.12598140308983674
# HANS,QNLI
# ---------
# alpha: 0.23404030811438215
# HANS,QQP
# ---------
# alpha: 0.19013888888888886
# HANS,RTE
# ---------
# alpha: 0.07431527913455627
# HANS,SST-2
# ---------
# alpha: 0.13802498670919716
# HANS,STS-B
# ---------
# alpha: 0.20759890325107722
# HANS,WNLI
# ---------
# alpha: 0.039871196497702543
# HANS_MNLI,MNLI
# ---------
# alpha: 0.11737038243062337
# HANS_MNLI,MNLI_TWO
# ---------
# alpha: 0.30409356725146197
# HANS_MNLI,MNLI_TWO_HALF
# ---------
# alpha: 0.30409356725146197
# HANS_MNLI,MRPC
# ---------
# alpha: 0.11114981229923748
# HANS_MNLI,QNLI
# ---------
# alpha: 0.2844444444444444
# HANS_MNLI,QQP
# ---------
# alpha: 0.16923868312757184
# HANS_MNLI,RTE
# ---------
# alpha: 0.05588451565463037
# HANS_MNLI,SST-2
# ---------
# alpha: 0.1488194444444444
# HANS_MNLI,STS-B
# ---------
# alpha: 0.18471035137701797
# HANS_MNLI,WNLI
# ---------
# alpha: 0.01619155432060626
# MNLI,MNLI_TWO
# ---------
# alpha: 0.17764752704511733
# MNLI,MNLI_TWO_HALF
# ---------
# alpha: 0.13459242374905034
# MNLI,MRPC
# ---------
# alpha: 0.051530934343434476
# MNLI,QNLI
# ---------
# alpha: 0.05943152454780365
# MNLI,QQP
# ---------
# alpha: 0.05333333333333323
# MNLI,RTE
# ---------
# alpha: 0.051530934343434254
# MNLI,SST-2
# ---------
# alpha: 0.058246280468502776
# MNLI,STS-B
# ---------
# alpha: 0.0896710232925112
# MNLI,WNLI
# ---------
# alpha: -0.017094017094017255
# MNLI_TWO,MNLI_TWO_HALF
# ---------
# alpha: 0.32106689487947504
# MNLI_TWO,MRPC
# ---------
# alpha: 0.13878246062154098
# MNLI_TWO,QNLI
# ---------
# alpha: 0.2222222222222221
# MNLI_TWO,QQP
# ---------
# alpha: 0.17798353909465014
# MNLI_TWO,RTE
# ---------
# alpha: 0.04667363288052939
# MNLI_TWO,SST-2
# ---------
# alpha: 0.14881944444444428
# MNLI_TWO,STS-B
# ---------
# alpha: 0.16856600189933513
# MNLI_TWO,WNLI
# ---------
# alpha: 0.008027168879283564
# MNLI_TWO_HALF,MRPC
# ---------
# alpha: 0.14799334339564219
# MNLI_TWO_HALF,QNLI
# ---------
# alpha: 0.29333333333333345
# MNLI_TWO_HALF,QQP
# ---------
# alpha: 0.23045267489711918
# MNLI_TWO_HALF,RTE
# ---------
# alpha: 0.028251867332326985
# MNLI_TWO_HALF,SST-2
# ---------
# alpha: 0.24798611111111102
# MNLI_TWO_HALF,STS-B
# ---------
# alpha: 0.19278252611585944
# MNLI_TWO_HALF,WNLI
# ---------
# alpha: 0.040684710644574684
# MRPC,QNLI
# ---------
# alpha: 0.06954732510288075
# MRPC,QQP
# ---------
# alpha: 0.09423704240666908
# MRPC,RTE
# ---------
# alpha: -0.036835748792270584
# MRPC,SST-2
# ---------
# alpha: 0.06222222222222229
# MRPC,STS-B
# ---------
# alpha: 0.11737038243062325
# MRPC,WNLI
# ---------
# alpha: -0.05653479566523045
# QNLI,QQP
# ---------
# alpha: 0.14799334339564219
# QNLI,RTE
# ---------
# alpha: -0.00880658436213988
# QNLI,SST-2
# ---------
# alpha: 0.1432034444082636
# QNLI,STS-B
# ---------
# alpha: 0.12521543385740908
# QNLI,WNLI
# ---------
# alpha: -0.028043593833067648
# QQP,RTE
# ---------
# alpha: -0.04953485562401827
# QQP,SST-2
# ---------
# alpha: 0.11738696334331755
# QQP,STS-B
# ---------
# alpha: 0.10749999999999993
# QQP,WNLI
# ---------
# alpha: -0.05027014329339918
# RTE,SST-2
# ---------
# alpha: -0.07111111111111112
# RTE,STS-B
# ---------
# alpha: 0.014038134520062195
# RTE,WNLI
# ---------
# alpha: -0.07984071027549278
# SST-2,STS-B
# ---------
# alpha: 0.05894471026049952
# SST-2,WNLI
# ---------
# alpha: -0.03383630544124383
# STS-B,WNLI
# ---------
# alpha: -0.020405948116791528

# %%
sets = []
for seed in heads['MNLI']:
    a = heads['MNLI'][seed]['head_mask'].reshape(-1)
    sets.append({x[0] for x in np.argwhere(a == 1)})

# %%
union =  set.union(*sets)
intersection = set.intersection(*sets)

# %%
len(intersection) / len(union)
# Out:
# 0.291970802919708
