# %%
# %matplotlib inline

# %%
import numpy as np
import pathlib
import matplotlib.pyplot as plt
import time
import json
import itertools
from statsmodels.stats.contingency_tables import cochrans_q

# %%
def load_head_data(experiments_path):
    head_data = {}
    for task_dir in experiments_path.iterdir():
        head_data[task_dir.stem] = {}
        for seed_dir in task_dir.iterdir():
            head_mask = np.load(seed_dir / "head_mask.npy")
            head_data[task_dir.stem][seed_dir.stem] = {
                "head_mask": head_mask,
            }
    return head_data
def load_mlp_data(experiments_path):
    mlp_data = {}
    for task_dir in experiments_path.iterdir():
        mlp_data[task_dir.stem] = {}
        for seed_dir in task_dir.iterdir():
            mlp_mask = np.load(seed_dir / "mlp_mask.npy")
            mlp_importance = np.load(seed_dir / "mlp_importance.npy")
            mlp_data[task_dir.stem][seed_dir.stem] = {
                "mlp_mask": mlp_mask,
                "mlp_importance": mlp_importance
            }
    return mlp_data

# %%
experiments_path = pathlib.Path("../masks/heads_mlps")
heads = load_head_data(experiments_path)

experiments_path = pathlib.Path("../masks/heads_mlps_hans")
hans_heads = load_head_data(experiments_path)

for k, v in hans_heads.items():
    heads[k] = v

experiments_path = pathlib.Path("../masks/heads_mlps")
mlps = load_mlp_data(experiments_path)




experiments_path = pathlib.Path("../masks/heads_mlps_hans")
hans_mlps = load_mlp_data(experiments_path)

for k, v in hans_mlps.items():
    mlps[k] = v

# %%
def cochrans_q_masks(masks):
    inp = np.array(masks).transpose()
    return cochrans_q(inp)


def print_p_value_tasks_separate(data, mask="head_mask"):
    for task in sorted(data.keys()):
        print_p_value_tasks(data, [task], mask)

        
def print_p_value_tasks(data, tasks, mask="head_mask"):
    masks = []
    seeds = sorted(data[tasks[0]].keys())
    for task in tasks:
        for seed in seeds:
            masks.append(data[task][seed][mask].reshape(-1))
    test_result = cochrans_q_masks(masks)
    print(','.join(tasks))
    print("---------------------------------------------------------------------")
    print(f'p-value: {test_result.pvalue}')
    print(f"{'Null hypothesis (all seeds are similar) is rejected.' if test_result.pvalue < 0.05 else 'Null hypothesis (all seeds are similar) is not rejected.'}")
    
    if len(tasks) == 1:
        masks_combos = list(itertools.combinations(range(len(masks)), 2))
    else:
        masks_combos = []
        for i in range(len(seeds)):
            for j in range(len(seeds)):
                if i < j:
                    mask_1_idx = i
                    mask_2_idx = len(seeds)  +  j
                    masks_combos.append((mask_1_idx, mask_2_idx))
    similar_masks_combos = []
    for mask_1, mask_2 in masks_combos:
        r = cochrans_q_masks([masks[mask_1], masks[mask_2]])
        if r.pvalue >= 0.05:
            task1_name, seed1_name = tasks[mask_1 // len(seeds)], seeds[mask_1 % len(seeds)]
            task2_name, seed2_name = tasks[mask_2 // len(seeds)], seeds[mask_2 % len(seeds)]
            similar_masks_combos.append((f"{task1_name}-{seed1_name}", f"{task2_name}-{seed2_name}"))
    
    print(f"Total mask pairs where Null hypothesis is not rejected - {len(similar_masks_combos)}")
    print(f"Total mask pairs - {len(masks_combos)}")
    print(f"Percentage - {len(similar_masks_combos)/ len(masks_combos)}")
    print("\nSimilar Mask Pairs:\n")
    print("\t".join([",".join(p) for p in similar_masks_combos]))
    print("\n\n")

# %% [markdown]
# # Seeds in a Task

# %% [markdown]
# ## Heads

# %%
print_p_value_tasks_separate(heads)
# Out:
# CoLA
# ---------------------------------------------------------------------
# p-value: 2.113894110905964e-11
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,CoLA-seed_42	CoLA-seed_1337,CoLA-seed_71	CoLA-seed_166,CoLA-seed_42
#
#
#
# HANS
# ---------------------------------------------------------------------
# p-value: 0.004749695087342902
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# HANS-seed_1337,HANS-seed_42	HANS-seed_1337,HANS-seed_71	HANS-seed_1337,HANS-seed_86	HANS-seed_166,HANS-seed_86	HANS-seed_42,HANS-seed_71	HANS-seed_42,HANS-seed_86	HANS-seed_71,HANS-seed_86
#
#
#
# HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 1.0701419296602784e-05
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,HANS_MNLI-seed_42	HANS_MNLI-seed_1337,HANS_MNLI-seed_86	HANS_MNLI-seed_166,HANS_MNLI-seed_42	HANS_MNLI-seed_71,HANS_MNLI-seed_86
#
#
#
# MNLI
# ---------------------------------------------------------------------
# p-value: 0.39484537126862373
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI-seed_166	MNLI-seed_1337,MNLI-seed_42	MNLI-seed_1337,MNLI-seed_71	MNLI-seed_1337,MNLI-seed_86	MNLI-seed_166,MNLI-seed_42	MNLI-seed_166,MNLI-seed_71	MNLI-seed_166,MNLI-seed_86	MNLI-seed_42,MNLI-seed_86	MNLI-seed_71,MNLI-seed_86
#
#
#
# MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.04886971480018394
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MNLI_TWO-seed_42	MNLI_TWO-seed_1337,MNLI_TWO-seed_71	MNLI_TWO-seed_1337,MNLI_TWO-seed_86	MNLI_TWO-seed_166,MNLI_TWO-seed_42	MNLI_TWO-seed_166,MNLI_TWO-seed_86	MNLI_TWO-seed_42,MNLI_TWO-seed_71	MNLI_TWO-seed_42,MNLI_TWO-seed_86	MNLI_TWO-seed_71,MNLI_TWO-seed_86
#
#
#
# MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.10751157701176865
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_166	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MRPC
# ---------------------------------------------------------------------
# p-value: 0.013837912255726509
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,MRPC-seed_166	MRPC-seed_1337,MRPC-seed_42	MRPC-seed_1337,MRPC-seed_71	MRPC-seed_1337,MRPC-seed_86	MRPC-seed_166,MRPC-seed_86	MRPC-seed_42,MRPC-seed_71	MRPC-seed_71,MRPC-seed_86
#
#
#
# QNLI
# ---------------------------------------------------------------------
# p-value: 0.0329959709332481
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,QNLI-seed_166	QNLI-seed_1337,QNLI-seed_71	QNLI-seed_1337,QNLI-seed_86	QNLI-seed_166,QNLI-seed_42	QNLI-seed_166,QNLI-seed_86	QNLI-seed_42,QNLI-seed_86
#
#
#
# QQP
# ---------------------------------------------------------------------
# p-value: 2.970583205868185e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# QQP-seed_1337,QQP-seed_166	QQP-seed_1337,QQP-seed_42	QQP-seed_166,QQP-seed_42	QQP-seed_71,QQP-seed_86
#
#
#
# RTE
# ---------------------------------------------------------------------
# p-value: 2.6922221869717934e-36
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 2
# Total mask pairs - 10
# Percentage - 0.2
#
# Similar Mask Pairs:
#
# RTE-seed_166,RTE-seed_71	RTE-seed_71,RTE-seed_86
#
#
#
# SST-2
# ---------------------------------------------------------------------
# p-value: 3.417832305517236e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 2
# Total mask pairs - 10
# Percentage - 0.2
#
# Similar Mask Pairs:
#
# SST-2-seed_42,SST-2-seed_86	SST-2-seed_71,SST-2-seed_86
#
#
#
# STS-B
# ---------------------------------------------------------------------
# p-value: 0.05786884035446416
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# STS-B-seed_1337,STS-B-seed_166	STS-B-seed_1337,STS-B-seed_42	STS-B-seed_1337,STS-B-seed_71	STS-B-seed_1337,STS-B-seed_86	STS-B-seed_166,STS-B-seed_42	STS-B-seed_166,STS-B-seed_86	STS-B-seed_42,STS-B-seed_71	STS-B-seed_42,STS-B-seed_86	STS-B-seed_71,STS-B-seed_86
#
#
#
# WNLI
# ---------------------------------------------------------------------
# p-value: 2.42151439227382e-123
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:

# %% [markdown]
# ## MLPs

# %%
print_p_value_tasks_separate(mlps, mask="mlp_mask")
# Out:
# CoLA
# ---------------------------------------------------------------------
# p-value: 0.3232398928813502
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,CoLA-seed_166	CoLA-seed_1337,CoLA-seed_42	CoLA-seed_1337,CoLA-seed_86	CoLA-seed_166,CoLA-seed_42	CoLA-seed_166,CoLA-seed_71	CoLA-seed_166,CoLA-seed_86	CoLA-seed_42,CoLA-seed_71	CoLA-seed_42,CoLA-seed_86	CoLA-seed_71,CoLA-seed_86
#
#
#
# HANS
# ---------------------------------------------------------------------
# p-value: 0.9594907270068882
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,HANS-seed_166	HANS-seed_1337,HANS-seed_42	HANS-seed_1337,HANS-seed_71	HANS-seed_1337,HANS-seed_86	HANS-seed_166,HANS-seed_42	HANS-seed_166,HANS-seed_71	HANS-seed_166,HANS-seed_86	HANS-seed_42,HANS-seed_71	HANS-seed_42,HANS-seed_86	HANS-seed_71,HANS-seed_86
#
#
#
# HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 0.9786790480094321
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,HANS_MNLI-seed_166	HANS_MNLI-seed_1337,HANS_MNLI-seed_42	HANS_MNLI-seed_1337,HANS_MNLI-seed_71	HANS_MNLI-seed_1337,HANS_MNLI-seed_86	HANS_MNLI-seed_166,HANS_MNLI-seed_42	HANS_MNLI-seed_166,HANS_MNLI-seed_71	HANS_MNLI-seed_166,HANS_MNLI-seed_86	HANS_MNLI-seed_42,HANS_MNLI-seed_71	HANS_MNLI-seed_42,HANS_MNLI-seed_86	HANS_MNLI-seed_71,HANS_MNLI-seed_86
#
#
#
# MNLI
# ---------------------------------------------------------------------
# p-value: 0.8224157057672481
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI-seed_166	MNLI-seed_1337,MNLI-seed_42	MNLI-seed_1337,MNLI-seed_71	MNLI-seed_1337,MNLI-seed_86	MNLI-seed_166,MNLI-seed_42	MNLI-seed_166,MNLI-seed_71	MNLI-seed_166,MNLI-seed_86	MNLI-seed_42,MNLI-seed_71	MNLI-seed_42,MNLI-seed_86	MNLI-seed_71,MNLI-seed_86
#
#
#
# MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.8312925312037189
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MNLI_TWO-seed_166	MNLI_TWO-seed_1337,MNLI_TWO-seed_42	MNLI_TWO-seed_1337,MNLI_TWO-seed_71	MNLI_TWO-seed_1337,MNLI_TWO-seed_86	MNLI_TWO-seed_166,MNLI_TWO-seed_42	MNLI_TWO-seed_166,MNLI_TWO-seed_71	MNLI_TWO-seed_166,MNLI_TWO-seed_86	MNLI_TWO-seed_42,MNLI_TWO-seed_71	MNLI_TWO-seed_42,MNLI_TWO-seed_86	MNLI_TWO-seed_71,MNLI_TWO-seed_86
#
#
#
# MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.5249309467861041
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_166	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_1337,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_42	MNLI_TWO_HALF-seed_166,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_42,MNLI_TWO_HALF-seed_71	MNLI_TWO_HALF-seed_42,MNLI_TWO_HALF-seed_86	MNLI_TWO_HALF-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MRPC
# ---------------------------------------------------------------------
# p-value: 0.6833711942656508
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,MRPC-seed_166	MRPC-seed_1337,MRPC-seed_42	MRPC-seed_1337,MRPC-seed_71	MRPC-seed_1337,MRPC-seed_86	MRPC-seed_166,MRPC-seed_71	MRPC-seed_166,MRPC-seed_86	MRPC-seed_42,MRPC-seed_71	MRPC-seed_42,MRPC-seed_86	MRPC-seed_71,MRPC-seed_86
#
#
#
# QNLI
# ---------------------------------------------------------------------
# p-value: 0.9824769036935782
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,QNLI-seed_166	QNLI-seed_1337,QNLI-seed_42	QNLI-seed_1337,QNLI-seed_71	QNLI-seed_1337,QNLI-seed_86	QNLI-seed_166,QNLI-seed_42	QNLI-seed_166,QNLI-seed_71	QNLI-seed_166,QNLI-seed_86	QNLI-seed_42,QNLI-seed_71	QNLI-seed_42,QNLI-seed_86	QNLI-seed_71,QNLI-seed_86
#
#
#
# QQP
# ---------------------------------------------------------------------
# p-value: 0.9735009788392561
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QQP-seed_1337,QQP-seed_166	QQP-seed_1337,QQP-seed_42	QQP-seed_1337,QQP-seed_71	QQP-seed_1337,QQP-seed_86	QQP-seed_166,QQP-seed_42	QQP-seed_166,QQP-seed_71	QQP-seed_166,QQP-seed_86	QQP-seed_42,QQP-seed_71	QQP-seed_42,QQP-seed_86	QQP-seed_71,QQP-seed_86
#
#
#
# RTE
# ---------------------------------------------------------------------
# p-value: 0.25477265448360564
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# RTE-seed_1337,RTE-seed_166	RTE-seed_1337,RTE-seed_42	RTE-seed_1337,RTE-seed_71	RTE-seed_166,RTE-seed_42	RTE-seed_166,RTE-seed_71	RTE-seed_166,RTE-seed_86	RTE-seed_42,RTE-seed_71	RTE-seed_42,RTE-seed_86	RTE-seed_71,RTE-seed_86
#
#
#
# SST-2
# ---------------------------------------------------------------------
# p-value: 0.8979161202208832
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# SST-2-seed_1337,SST-2-seed_166	SST-2-seed_1337,SST-2-seed_42	SST-2-seed_1337,SST-2-seed_71	SST-2-seed_1337,SST-2-seed_86	SST-2-seed_166,SST-2-seed_42	SST-2-seed_166,SST-2-seed_71	SST-2-seed_166,SST-2-seed_86	SST-2-seed_42,SST-2-seed_71	SST-2-seed_42,SST-2-seed_86	SST-2-seed_71,SST-2-seed_86
#
#
#
# STS-B
# ---------------------------------------------------------------------
# p-value: 0.47205433276263287
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# STS-B-seed_1337,STS-B-seed_166	STS-B-seed_1337,STS-B-seed_42	STS-B-seed_1337,STS-B-seed_71	STS-B-seed_1337,STS-B-seed_86	STS-B-seed_166,STS-B-seed_42	STS-B-seed_166,STS-B-seed_71	STS-B-seed_166,STS-B-seed_86	STS-B-seed_42,STS-B-seed_71	STS-B-seed_42,STS-B-seed_86	STS-B-seed_71,STS-B-seed_86
#
#
#
# WNLI
# ---------------------------------------------------------------------
# p-value: nan
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:

# %% [markdown]
# ## Pairwise Task to task comparison

# %% [markdown]
# # Heads

# %%
tasks = sorted(heads.keys())
for t1, t2 in itertools.combinations(tasks, 2):
    print_p_value_tasks(heads, [t1, t2])
# Out:
# CoLA,HANS
# ---------------------------------------------------------------------
# p-value: 1.770648917866998e-23
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# CoLA-seed_166,HANS-seed_42	CoLA-seed_166,HANS-seed_71	CoLA-seed_166,HANS-seed_86	CoLA-seed_42,HANS-seed_71
#
#
#
# CoLA,HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 6.504899929147611e-15
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,HANS_MNLI-seed_166	CoLA-seed_1337,HANS_MNLI-seed_42	CoLA-seed_166,HANS_MNLI-seed_71	CoLA-seed_166,HANS_MNLI-seed_86	CoLA-seed_42,HANS_MNLI-seed_86
#
#
#
# CoLA,MNLI
# ---------------------------------------------------------------------
# p-value: 1.027240403810406e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MNLI-seed_166	CoLA-seed_1337,MNLI-seed_42	CoLA-seed_1337,MNLI-seed_71	CoLA-seed_1337,MNLI-seed_86	CoLA-seed_42,MNLI-seed_71	CoLA-seed_42,MNLI-seed_86	CoLA-seed_71,MNLI-seed_86
#
#
#
# CoLA,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 7.510123906511181e-17
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MNLI_TWO-seed_166	CoLA-seed_166,MNLI_TWO-seed_42	CoLA-seed_166,MNLI_TWO-seed_71	CoLA-seed_166,MNLI_TWO-seed_86	CoLA-seed_42,MNLI_TWO-seed_86
#
#
#
# CoLA,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 1.2023715374261755e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MNLI_TWO_HALF-seed_166	CoLA-seed_1337,MNLI_TWO_HALF-seed_71	CoLA-seed_1337,MNLI_TWO_HALF-seed_86	CoLA-seed_166,MNLI_TWO_HALF-seed_42	CoLA-seed_42,MNLI_TWO_HALF-seed_71	CoLA-seed_42,MNLI_TWO_HALF-seed_86	CoLA-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# CoLA,MRPC
# ---------------------------------------------------------------------
# p-value: 6.453344907855591e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MRPC-seed_166	CoLA-seed_1337,MRPC-seed_42	CoLA-seed_1337,MRPC-seed_71	CoLA-seed_1337,MRPC-seed_86	CoLA-seed_166,MRPC-seed_42	CoLA-seed_42,MRPC-seed_71	CoLA-seed_42,MRPC-seed_86	CoLA-seed_71,MRPC-seed_86
#
#
#
# CoLA,QNLI
# ---------------------------------------------------------------------
# p-value: 1.847871458493687e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,QNLI-seed_166	CoLA-seed_1337,QNLI-seed_42	CoLA-seed_1337,QNLI-seed_86	CoLA-seed_166,QNLI-seed_71	CoLA-seed_42,QNLI-seed_71	CoLA-seed_42,QNLI-seed_86	CoLA-seed_71,QNLI-seed_86
#
#
#
# CoLA,QQP
# ---------------------------------------------------------------------
# p-value: 5.567137351738215e-17
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,QQP-seed_71	CoLA-seed_1337,QQP-seed_86	CoLA-seed_166,QQP-seed_42	CoLA-seed_42,QQP-seed_86	CoLA-seed_71,QQP-seed_86
#
#
#
# CoLA,RTE
# ---------------------------------------------------------------------
# p-value: 5.235255045002162e-47
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,RTE-seed_166	CoLA-seed_166,RTE-seed_71	CoLA-seed_166,RTE-seed_86	CoLA-seed_42,RTE-seed_71	CoLA-seed_42,RTE-seed_86
#
#
#
# CoLA,SST-2
# ---------------------------------------------------------------------
# p-value: 1.621999207840264e-25
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# CoLA-seed_166,SST-2-seed_42	CoLA-seed_166,SST-2-seed_71	CoLA-seed_166,SST-2-seed_86	CoLA-seed_42,SST-2-seed_86
#
#
#
# CoLA,STS-B
# ---------------------------------------------------------------------
# p-value: 9.137643528501942e-13
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,STS-B-seed_71	CoLA-seed_1337,STS-B-seed_86	CoLA-seed_166,STS-B-seed_42	CoLA-seed_42,STS-B-seed_71	CoLA-seed_42,STS-B-seed_86
#
#
#
# CoLA,WNLI
# ---------------------------------------------------------------------
# p-value: 1.3310266521015885e-164
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# HANS,HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 2.918579035833134e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# HANS-seed_1337,HANS_MNLI-seed_71	HANS-seed_1337,HANS_MNLI-seed_86	HANS-seed_42,HANS_MNLI-seed_71	HANS-seed_42,HANS_MNLI-seed_86	HANS-seed_71,HANS_MNLI-seed_86
#
#
#
# HANS,MNLI
# ---------------------------------------------------------------------
# p-value: 2.8551882175671094e-18
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# HANS,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.0011505179826728014
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MNLI_TWO-seed_166	HANS-seed_1337,MNLI_TWO-seed_42	HANS-seed_1337,MNLI_TWO-seed_71	HANS-seed_1337,MNLI_TWO-seed_86	HANS-seed_166,MNLI_TWO-seed_71	HANS-seed_42,MNLI_TWO-seed_71	HANS-seed_42,MNLI_TWO-seed_86	HANS-seed_71,MNLI_TWO-seed_86
#
#
#
# HANS,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 1.4870428296994807e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MNLI_TWO_HALF-seed_166	HANS-seed_1337,MNLI_TWO_HALF-seed_42	HANS-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# HANS,MRPC
# ---------------------------------------------------------------------
# p-value: 3.6006246442701404e-14
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MRPC-seed_42	HANS-seed_1337,MRPC-seed_71	HANS-seed_42,MRPC-seed_71
#
#
#
# HANS,QNLI
# ---------------------------------------------------------------------
# p-value: 1.6778836677666836e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# HANS-seed_1337,QNLI-seed_71	HANS-seed_42,QNLI-seed_71	HANS-seed_71,QNLI-seed_86
#
#
#
# HANS,QQP
# ---------------------------------------------------------------------
# p-value: 9.33380262403033e-11
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# HANS-seed_1337,QQP-seed_166	HANS-seed_1337,QQP-seed_42	HANS-seed_71,QQP-seed_86
#
#
#
# HANS,RTE
# ---------------------------------------------------------------------
# p-value: 4.400065747443525e-36
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# HANS-seed_1337,RTE-seed_71	HANS-seed_1337,RTE-seed_86	HANS-seed_42,RTE-seed_71	HANS-seed_42,RTE-seed_86	HANS-seed_71,RTE-seed_86
#
#
#
# HANS,SST-2
# ---------------------------------------------------------------------
# p-value: 1.044150482904166e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# HANS-seed_1337,SST-2-seed_42	HANS-seed_1337,SST-2-seed_71	HANS-seed_1337,SST-2-seed_86	HANS-seed_166,SST-2-seed_71	HANS-seed_42,SST-2-seed_71	HANS-seed_42,SST-2-seed_86	HANS-seed_71,SST-2-seed_86
#
#
#
# HANS,STS-B
# ---------------------------------------------------------------------
# p-value: 1.2423453801450991e-05
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# HANS-seed_1337,STS-B-seed_166	HANS-seed_1337,STS-B-seed_42	HANS-seed_1337,STS-B-seed_86	HANS-seed_42,STS-B-seed_86	HANS-seed_71,STS-B-seed_86
#
#
#
# HANS,WNLI
# ---------------------------------------------------------------------
# p-value: 3.491199799700724e-130
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# HANS_MNLI,MNLI
# ---------------------------------------------------------------------
# p-value: 3.824860788159743e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MNLI-seed_166	HANS_MNLI-seed_1337,MNLI-seed_71	HANS_MNLI-seed_1337,MNLI-seed_86	HANS_MNLI-seed_166,MNLI-seed_42	HANS_MNLI-seed_166,MNLI-seed_71	HANS_MNLI-seed_166,MNLI-seed_86	HANS_MNLI-seed_42,MNLI-seed_71	HANS_MNLI-seed_42,MNLI-seed_86
#
#
#
# HANS_MNLI,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 8.445987427090138e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MNLI_TWO-seed_166	HANS_MNLI-seed_1337,MNLI_TWO-seed_42	HANS_MNLI-seed_1337,MNLI_TWO-seed_86	HANS_MNLI-seed_71,MNLI_TWO-seed_86
#
#
#
# HANS_MNLI,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 7.259181451795303e-05
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_166	HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_42	HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_71	HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_86	HANS_MNLI-seed_166,MNLI_TWO_HALF-seed_71	HANS_MNLI-seed_166,MNLI_TWO_HALF-seed_86	HANS_MNLI-seed_42,MNLI_TWO_HALF-seed_71	HANS_MNLI-seed_42,MNLI_TWO_HALF-seed_86
#
#
#
# HANS_MNLI,MRPC
# ---------------------------------------------------------------------
# p-value: 6.938996275244432e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MRPC-seed_42	HANS_MNLI-seed_1337,MRPC-seed_71	HANS_MNLI-seed_1337,MRPC-seed_86	HANS_MNLI-seed_166,MRPC-seed_42	HANS_MNLI-seed_166,MRPC-seed_71	HANS_MNLI-seed_166,MRPC-seed_86	HANS_MNLI-seed_42,MRPC-seed_71	HANS_MNLI-seed_42,MRPC-seed_86
#
#
#
# HANS_MNLI,QNLI
# ---------------------------------------------------------------------
# p-value: 1.361968969885572e-05
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,QNLI-seed_166	HANS_MNLI-seed_1337,QNLI-seed_42	HANS_MNLI-seed_1337,QNLI-seed_71	HANS_MNLI-seed_1337,QNLI-seed_86	HANS_MNLI-seed_166,QNLI-seed_42	HANS_MNLI-seed_166,QNLI-seed_86	HANS_MNLI-seed_42,QNLI-seed_71	HANS_MNLI-seed_42,QNLI-seed_86
#
#
#
# HANS_MNLI,QQP
# ---------------------------------------------------------------------
# p-value: 8.701810029278109e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,QQP-seed_166	HANS_MNLI-seed_1337,QQP-seed_42	HANS_MNLI-seed_1337,QQP-seed_86	HANS_MNLI-seed_166,QQP-seed_71	HANS_MNLI-seed_166,QQP-seed_86	HANS_MNLI-seed_42,QQP-seed_71	HANS_MNLI-seed_42,QQP-seed_86
#
#
#
# HANS_MNLI,RTE
# ---------------------------------------------------------------------
# p-value: 2.534143122440279e-37
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,RTE-seed_166	HANS_MNLI-seed_1337,RTE-seed_71	HANS_MNLI-seed_1337,RTE-seed_86	HANS_MNLI-seed_42,RTE-seed_71	HANS_MNLI-seed_42,RTE-seed_86	HANS_MNLI-seed_71,RTE-seed_86
#
#
#
# HANS_MNLI,SST-2
# ---------------------------------------------------------------------
# p-value: 9.054137803792027e-12
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,SST-2-seed_42	HANS_MNLI-seed_1337,SST-2-seed_86	HANS_MNLI-seed_71,SST-2-seed_86
#
#
#
# HANS_MNLI,STS-B
# ---------------------------------------------------------------------
# p-value: 0.00011745667634079254
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,STS-B-seed_166	HANS_MNLI-seed_1337,STS-B-seed_42	HANS_MNLI-seed_1337,STS-B-seed_71	HANS_MNLI-seed_1337,STS-B-seed_86	HANS_MNLI-seed_166,STS-B-seed_71	HANS_MNLI-seed_166,STS-B-seed_86	HANS_MNLI-seed_42,STS-B-seed_71	HANS_MNLI-seed_42,STS-B-seed_86
#
#
#
# HANS_MNLI,WNLI
# ---------------------------------------------------------------------
# p-value: 1.4251758860616334e-147
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 4.863520077737301e-12
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 1
# Total mask pairs - 10
# Percentage - 0.1
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI_TWO-seed_166
#
#
#
# MNLI,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.0002990237266109789
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI_TWO_HALF-seed_166	MNLI-seed_1337,MNLI_TWO_HALF-seed_71	MNLI-seed_1337,MNLI_TWO_HALF-seed_86	MNLI-seed_166,MNLI_TWO_HALF-seed_71	MNLI-seed_166,MNLI_TWO_HALF-seed_86	MNLI-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MNLI,MRPC
# ---------------------------------------------------------------------
# p-value: 0.023241574412240375
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MRPC-seed_166	MNLI-seed_1337,MRPC-seed_42	MNLI-seed_1337,MRPC-seed_71	MNLI-seed_1337,MRPC-seed_86	MNLI-seed_166,MRPC-seed_42	MNLI-seed_166,MRPC-seed_71	MNLI-seed_166,MRPC-seed_86	MNLI-seed_42,MRPC-seed_86	MNLI-seed_71,MRPC-seed_86
#
#
#
# MNLI,QNLI
# ---------------------------------------------------------------------
# p-value: 0.006770090521934628
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,QNLI-seed_166	MNLI-seed_1337,QNLI-seed_42	MNLI-seed_1337,QNLI-seed_86	MNLI-seed_166,QNLI-seed_42	MNLI-seed_166,QNLI-seed_86	MNLI-seed_42,QNLI-seed_86	MNLI-seed_71,QNLI-seed_86
#
#
#
# MNLI,QQP
# ---------------------------------------------------------------------
# p-value: 3.169146039198427e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,QQP-seed_71	MNLI-seed_1337,QQP-seed_86	MNLI-seed_166,QQP-seed_71	MNLI-seed_166,QQP-seed_86	MNLI-seed_42,QQP-seed_71	MNLI-seed_42,QQP-seed_86	MNLI-seed_71,QQP-seed_86
#
#
#
# MNLI,RTE
# ---------------------------------------------------------------------
# p-value: 9.51795588758136e-42
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 1
# Total mask pairs - 10
# Percentage - 0.1
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,RTE-seed_166
#
#
#
# MNLI,SST-2
# ---------------------------------------------------------------------
# p-value: 1.312598158633592e-18
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI,STS-B
# ---------------------------------------------------------------------
# p-value: 4.96165354954623e-06
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,STS-B-seed_71	MNLI-seed_1337,STS-B-seed_86	MNLI-seed_166,STS-B-seed_71	MNLI-seed_166,STS-B-seed_86	MNLI-seed_42,STS-B-seed_71	MNLI-seed_71,STS-B-seed_86
#
#
#
# MNLI,WNLI
# ---------------------------------------------------------------------
# p-value: 1.7051177120733952e-161
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI_TWO,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.0006849228001192094
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MNLI_TWO_HALF-seed_166	MNLI_TWO-seed_1337,MNLI_TWO_HALF-seed_42	MNLI_TWO-seed_166,MNLI_TWO_HALF-seed_42	MNLI_TWO-seed_166,MNLI_TWO_HALF-seed_71	MNLI_TWO-seed_166,MNLI_TWO_HALF-seed_86	MNLI_TWO-seed_42,MNLI_TWO_HALF-seed_71	MNLI_TWO-seed_42,MNLI_TWO_HALF-seed_86
#
#
#
# MNLI_TWO,MRPC
# ---------------------------------------------------------------------
# p-value: 1.649174507195374e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MRPC-seed_42	MNLI_TWO-seed_1337,MRPC-seed_71	MNLI_TWO-seed_166,MRPC-seed_42	MNLI_TWO-seed_166,MRPC-seed_71	MNLI_TWO-seed_166,MRPC-seed_86	MNLI_TWO-seed_42,MRPC-seed_71
#
#
#
# MNLI_TWO,QNLI
# ---------------------------------------------------------------------
# p-value: 5.0332093714979585e-06
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,QNLI-seed_71	MNLI_TWO-seed_166,QNLI-seed_42	MNLI_TWO-seed_166,QNLI-seed_71	MNLI_TWO-seed_166,QNLI-seed_86	MNLI_TWO-seed_42,QNLI-seed_71
#
#
#
# MNLI_TWO,QQP
# ---------------------------------------------------------------------
# p-value: 9.287217204051631e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,QQP-seed_166	MNLI_TWO-seed_1337,QQP-seed_42	MNLI_TWO-seed_166,QQP-seed_42	MNLI_TWO-seed_166,QQP-seed_86	MNLI_TWO-seed_42,QQP-seed_86
#
#
#
# MNLI_TWO,RTE
# ---------------------------------------------------------------------
# p-value: 1.2694855256228898e-34
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,RTE-seed_71	MNLI_TWO-seed_1337,RTE-seed_86	MNLI_TWO-seed_166,RTE-seed_71	MNLI_TWO-seed_166,RTE-seed_86	MNLI_TWO-seed_42,RTE-seed_71	MNLI_TWO-seed_42,RTE-seed_86	MNLI_TWO-seed_71,RTE-seed_86
#
#
#
# MNLI_TWO,SST-2
# ---------------------------------------------------------------------
# p-value: 2.349562088668922e-06
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,SST-2-seed_42	MNLI_TWO-seed_1337,SST-2-seed_71	MNLI_TWO-seed_1337,SST-2-seed_86	MNLI_TWO-seed_166,SST-2-seed_42	MNLI_TWO-seed_166,SST-2-seed_86	MNLI_TWO-seed_42,SST-2-seed_71	MNLI_TWO-seed_42,SST-2-seed_86	MNLI_TWO-seed_71,SST-2-seed_86
#
#
#
# MNLI_TWO,STS-B
# ---------------------------------------------------------------------
# p-value: 0.00986217737831588
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,STS-B-seed_166	MNLI_TWO-seed_1337,STS-B-seed_42	MNLI_TWO-seed_1337,STS-B-seed_86	MNLI_TWO-seed_166,STS-B-seed_42	MNLI_TWO-seed_166,STS-B-seed_71	MNLI_TWO-seed_166,STS-B-seed_86	MNLI_TWO-seed_42,STS-B-seed_71	MNLI_TWO-seed_42,STS-B-seed_86
#
#
#
# MNLI_TWO,WNLI
# ---------------------------------------------------------------------
# p-value: 6.1011629141954964e-136
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI_TWO_HALF,MRPC
# ---------------------------------------------------------------------
# p-value: 0.001927111775741515
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,MRPC-seed_42	MNLI_TWO_HALF-seed_1337,MRPC-seed_71	MNLI_TWO_HALF-seed_166,MRPC-seed_42	MNLI_TWO_HALF-seed_166,MRPC-seed_71	MNLI_TWO_HALF-seed_166,MRPC-seed_86	MNLI_TWO_HALF-seed_42,MRPC-seed_71	MNLI_TWO_HALF-seed_71,MRPC-seed_86
#
#
#
# MNLI_TWO_HALF,QNLI
# ---------------------------------------------------------------------
# p-value: 0.02143833942820825
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,QNLI-seed_166	MNLI_TWO_HALF-seed_1337,QNLI-seed_71	MNLI_TWO_HALF-seed_1337,QNLI-seed_86	MNLI_TWO_HALF-seed_166,QNLI-seed_42	MNLI_TWO_HALF-seed_166,QNLI-seed_71	MNLI_TWO_HALF-seed_166,QNLI-seed_86	MNLI_TWO_HALF-seed_42,QNLI-seed_71	MNLI_TWO_HALF-seed_71,QNLI-seed_86
#
#
#
# MNLI_TWO_HALF,QQP
# ---------------------------------------------------------------------
# p-value: 1.6561580395404268e-06
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,QQP-seed_166	MNLI_TWO_HALF-seed_1337,QQP-seed_42	MNLI_TWO_HALF-seed_1337,QQP-seed_86	MNLI_TWO_HALF-seed_166,QQP-seed_42	MNLI_TWO_HALF-seed_166,QQP-seed_86	MNLI_TWO_HALF-seed_42,QQP-seed_86	MNLI_TWO_HALF-seed_71,QQP-seed_86
#
#
#
# MNLI_TWO_HALF,RTE
# ---------------------------------------------------------------------
# p-value: 2.022005705483577e-36
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,RTE-seed_166	MNLI_TWO_HALF-seed_1337,RTE-seed_71	MNLI_TWO_HALF-seed_1337,RTE-seed_86	MNLI_TWO_HALF-seed_166,RTE-seed_71	MNLI_TWO_HALF-seed_166,RTE-seed_86	MNLI_TWO_HALF-seed_42,RTE-seed_71	MNLI_TWO_HALF-seed_42,RTE-seed_86	MNLI_TWO_HALF-seed_71,RTE-seed_86
#
#
#
# MNLI_TWO_HALF,SST-2
# ---------------------------------------------------------------------
# p-value: 8.031815895378768e-09
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,SST-2-seed_42	MNLI_TWO_HALF-seed_1337,SST-2-seed_71	MNLI_TWO_HALF-seed_1337,SST-2-seed_86	MNLI_TWO_HALF-seed_166,SST-2-seed_42	MNLI_TWO_HALF-seed_166,SST-2-seed_86	MNLI_TWO_HALF-seed_42,SST-2-seed_71	MNLI_TWO_HALF-seed_42,SST-2-seed_86
#
#
#
# MNLI_TWO_HALF,STS-B
# ---------------------------------------------------------------------
# p-value: 0.04820345003056944
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,STS-B-seed_166	MNLI_TWO_HALF-seed_1337,STS-B-seed_42	MNLI_TWO_HALF-seed_1337,STS-B-seed_71	MNLI_TWO_HALF-seed_1337,STS-B-seed_86	MNLI_TWO_HALF-seed_166,STS-B-seed_42	MNLI_TWO_HALF-seed_166,STS-B-seed_71	MNLI_TWO_HALF-seed_166,STS-B-seed_86	MNLI_TWO_HALF-seed_42,STS-B-seed_71	MNLI_TWO_HALF-seed_42,STS-B-seed_86	MNLI_TWO_HALF-seed_71,STS-B-seed_86
#
#
#
# MNLI_TWO_HALF,WNLI
# ---------------------------------------------------------------------
# p-value: 3.1439745864814084e-145
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MRPC,QNLI
# ---------------------------------------------------------------------
# p-value: 0.005280135052655448
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,QNLI-seed_166	MRPC-seed_1337,QNLI-seed_42	MRPC-seed_1337,QNLI-seed_71	MRPC-seed_1337,QNLI-seed_86	MRPC-seed_166,QNLI-seed_42	MRPC-seed_166,QNLI-seed_86	MRPC-seed_42,QNLI-seed_71	MRPC-seed_42,QNLI-seed_86	MRPC-seed_71,QNLI-seed_86
#
#
#
# MRPC,QQP
# ---------------------------------------------------------------------
# p-value: 5.273748825983456e-09
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,QQP-seed_71	MRPC-seed_1337,QQP-seed_86	MRPC-seed_166,QQP-seed_71	MRPC-seed_166,QQP-seed_86	MRPC-seed_42,QQP-seed_86	MRPC-seed_71,QQP-seed_86
#
#
#
# MRPC,RTE
# ---------------------------------------------------------------------
# p-value: 1.1574414783006666e-39
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,RTE-seed_166	MRPC-seed_1337,RTE-seed_71	MRPC-seed_42,RTE-seed_71	MRPC-seed_42,RTE-seed_86	MRPC-seed_71,RTE-seed_86
#
#
#
# MRPC,SST-2
# ---------------------------------------------------------------------
# p-value: 3.0972686270654594e-14
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 3
# Total mask pairs - 10
# Percentage - 0.3
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,SST-2-seed_42	MRPC-seed_42,SST-2-seed_86	MRPC-seed_71,SST-2-seed_86
#
#
#
# MRPC,STS-B
# ---------------------------------------------------------------------
# p-value: 5.3937400363043054e-05
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,STS-B-seed_42	MRPC-seed_1337,STS-B-seed_71	MRPC-seed_1337,STS-B-seed_86	MRPC-seed_166,STS-B-seed_71	MRPC-seed_42,STS-B-seed_71	MRPC-seed_42,STS-B-seed_86	MRPC-seed_71,STS-B-seed_86
#
#
#
# MRPC,WNLI
# ---------------------------------------------------------------------
# p-value: 8.97575313429447e-154
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# QNLI,QQP
# ---------------------------------------------------------------------
# p-value: 8.618447659943853e-08
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 7
# Total mask pairs - 10
# Percentage - 0.7
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,QQP-seed_166	QNLI-seed_1337,QQP-seed_42	QNLI-seed_1337,QQP-seed_86	QNLI-seed_166,QQP-seed_86	QNLI-seed_42,QQP-seed_71	QNLI-seed_42,QQP-seed_86	QNLI-seed_71,QQP-seed_86
#
#
#
# QNLI,RTE
# ---------------------------------------------------------------------
# p-value: 2.541526817297776e-38
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,RTE-seed_166	QNLI-seed_1337,RTE-seed_71	QNLI-seed_1337,RTE-seed_86	QNLI-seed_166,RTE-seed_71	QNLI-seed_166,RTE-seed_86	QNLI-seed_71,RTE-seed_86
#
#
#
# QNLI,SST-2
# ---------------------------------------------------------------------
# p-value: 6.692476698596474e-11
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,SST-2-seed_42	QNLI-seed_1337,SST-2-seed_86	QNLI-seed_166,SST-2-seed_42	QNLI-seed_71,SST-2-seed_86
#
#
#
# QNLI,STS-B
# ---------------------------------------------------------------------
# p-value: 0.004721201689601216
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,STS-B-seed_166	QNLI-seed_1337,STS-B-seed_42	QNLI-seed_1337,STS-B-seed_71	QNLI-seed_1337,STS-B-seed_86	QNLI-seed_166,STS-B-seed_42	QNLI-seed_166,STS-B-seed_71	QNLI-seed_166,STS-B-seed_86	QNLI-seed_42,STS-B-seed_71	QNLI-seed_42,STS-B-seed_86	QNLI-seed_71,STS-B-seed_86
#
#
#
# QNLI,WNLI
# ---------------------------------------------------------------------
# p-value: 3.47441589753988e-151
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# QQP,RTE
# ---------------------------------------------------------------------
# p-value: 6.26924555354585e-38
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# QQP-seed_1337,RTE-seed_71	QQP-seed_1337,RTE-seed_86	QQP-seed_166,RTE-seed_71	QQP-seed_166,RTE-seed_86	QQP-seed_42,RTE-seed_71	QQP-seed_42,RTE-seed_86
#
#
#
# QQP,SST-2
# ---------------------------------------------------------------------
# p-value: 1.681804427778477e-12
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# QQP-seed_1337,SST-2-seed_42	QQP-seed_1337,SST-2-seed_71	QQP-seed_1337,SST-2-seed_86	QQP-seed_166,SST-2-seed_42	QQP-seed_166,SST-2-seed_71	QQP-seed_166,SST-2-seed_86	QQP-seed_42,SST-2-seed_71	QQP-seed_42,SST-2-seed_86
#
#
#
# QQP,STS-B
# ---------------------------------------------------------------------
# p-value: 1.9780379813569143e-06
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# QQP-seed_1337,STS-B-seed_166	QQP-seed_1337,STS-B-seed_42	QQP-seed_1337,STS-B-seed_86	QQP-seed_166,STS-B-seed_42	QQP-seed_166,STS-B-seed_86	QQP-seed_42,STS-B-seed_86
#
#
#
# QQP,WNLI
# ---------------------------------------------------------------------
# p-value: 4.485867085109875e-145
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# RTE,SST-2
# ---------------------------------------------------------------------
# p-value: 1.146364121388389e-38
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 2
# Total mask pairs - 10
# Percentage - 0.2
#
# Similar Mask Pairs:
#
# RTE-seed_166,SST-2-seed_42	RTE-seed_71,SST-2-seed_86
#
#
#
# RTE,STS-B
# ---------------------------------------------------------------------
# p-value: 5.874746774846481e-35
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 4
# Total mask pairs - 10
# Percentage - 0.4
#
# Similar Mask Pairs:
#
# RTE-seed_166,STS-B-seed_42	RTE-seed_166,STS-B-seed_71	RTE-seed_166,STS-B-seed_86	RTE-seed_71,STS-B-seed_86
#
#
#
# RTE,WNLI
# ---------------------------------------------------------------------
# p-value: 1.9258808339045054e-167
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# SST-2,STS-B
# ---------------------------------------------------------------------
# p-value: 3.177079759511013e-07
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# SST-2-seed_1337,STS-B-seed_42	SST-2-seed_1337,STS-B-seed_71	SST-2-seed_1337,STS-B-seed_86	SST-2-seed_42,STS-B-seed_71	SST-2-seed_42,STS-B-seed_86
#
#
#
# SST-2,WNLI
# ---------------------------------------------------------------------
# p-value: 8.42649476245913e-142
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# STS-B,WNLI
# ---------------------------------------------------------------------
# p-value: 6.861061114606823e-140
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:

# %% [markdown]
# ## MLPs

# %%
for t1, t2 in itertools.combinations(tasks, 2):
    print_p_value_tasks(mlps, [t1, t2], mask="mlp_mask")
# Out:
# CoLA,HANS
# ---------------------------------------------------------------------
# p-value: 0.02432935515164265
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,HANS-seed_166	CoLA-seed_1337,HANS-seed_71	CoLA-seed_166,HANS-seed_42	CoLA-seed_166,HANS-seed_71	CoLA-seed_166,HANS-seed_86
#
#
#
# CoLA,HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 0.15879295358012627
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,HANS_MNLI-seed_166	CoLA-seed_1337,HANS_MNLI-seed_42	CoLA-seed_1337,HANS_MNLI-seed_71	CoLA-seed_1337,HANS_MNLI-seed_86	CoLA-seed_166,HANS_MNLI-seed_42	CoLA-seed_166,HANS_MNLI-seed_71	CoLA-seed_166,HANS_MNLI-seed_86	CoLA-seed_71,HANS_MNLI-seed_86
#
#
#
# CoLA,MNLI
# ---------------------------------------------------------------------
# p-value: 0.13334696176542207
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MNLI-seed_166	CoLA-seed_1337,MNLI-seed_42	CoLA-seed_1337,MNLI-seed_86	CoLA-seed_166,MNLI-seed_42	CoLA-seed_166,MNLI-seed_71	CoLA-seed_166,MNLI-seed_86	CoLA-seed_42,MNLI-seed_86	CoLA-seed_71,MNLI-seed_86
#
#
#
# CoLA,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.09712923065823799
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MNLI_TWO-seed_166	CoLA-seed_1337,MNLI_TWO-seed_42	CoLA-seed_1337,MNLI_TWO-seed_71	CoLA-seed_1337,MNLI_TWO-seed_86	CoLA-seed_166,MNLI_TWO-seed_42	CoLA-seed_166,MNLI_TWO-seed_71	CoLA-seed_166,MNLI_TWO-seed_86	CoLA-seed_42,MNLI_TWO-seed_71	CoLA-seed_42,MNLI_TWO-seed_86	CoLA-seed_71,MNLI_TWO-seed_86
#
#
#
# CoLA,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.09661705849688125
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MNLI_TWO_HALF-seed_166	CoLA-seed_1337,MNLI_TWO_HALF-seed_42	CoLA-seed_1337,MNLI_TWO_HALF-seed_71	CoLA-seed_1337,MNLI_TWO_HALF-seed_86	CoLA-seed_166,MNLI_TWO_HALF-seed_42	CoLA-seed_166,MNLI_TWO_HALF-seed_71	CoLA-seed_166,MNLI_TWO_HALF-seed_86	CoLA-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# CoLA,MRPC
# ---------------------------------------------------------------------
# p-value: 0.3504852123233613
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,MRPC-seed_166	CoLA-seed_1337,MRPC-seed_42	CoLA-seed_1337,MRPC-seed_71	CoLA-seed_1337,MRPC-seed_86	CoLA-seed_166,MRPC-seed_42	CoLA-seed_166,MRPC-seed_71	CoLA-seed_166,MRPC-seed_86	CoLA-seed_42,MRPC-seed_71	CoLA-seed_42,MRPC-seed_86	CoLA-seed_71,MRPC-seed_86
#
#
#
# CoLA,QNLI
# ---------------------------------------------------------------------
# p-value: 0.4846458858263931
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,QNLI-seed_166	CoLA-seed_1337,QNLI-seed_42	CoLA-seed_1337,QNLI-seed_71	CoLA-seed_1337,QNLI-seed_86	CoLA-seed_166,QNLI-seed_42	CoLA-seed_166,QNLI-seed_71	CoLA-seed_166,QNLI-seed_86	CoLA-seed_42,QNLI-seed_71	CoLA-seed_42,QNLI-seed_86	CoLA-seed_71,QNLI-seed_86
#
#
#
# CoLA,QQP
# ---------------------------------------------------------------------
# p-value: 0.38416719818569
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,QQP-seed_166	CoLA-seed_1337,QQP-seed_42	CoLA-seed_1337,QQP-seed_71	CoLA-seed_1337,QQP-seed_86	CoLA-seed_166,QQP-seed_42	CoLA-seed_166,QQP-seed_71	CoLA-seed_166,QQP-seed_86	CoLA-seed_42,QQP-seed_71	CoLA-seed_42,QQP-seed_86	CoLA-seed_71,QQP-seed_86
#
#
#
# CoLA,RTE
# ---------------------------------------------------------------------
# p-value: 0.11733349569642
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 6
# Total mask pairs - 10
# Percentage - 0.6
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,RTE-seed_166	CoLA-seed_1337,RTE-seed_42	CoLA-seed_1337,RTE-seed_71	CoLA-seed_166,RTE-seed_42	CoLA-seed_166,RTE-seed_71	CoLA-seed_166,RTE-seed_86
#
#
#
# CoLA,SST-2
# ---------------------------------------------------------------------
# p-value: 0.12331127694886172
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,SST-2-seed_166	CoLA-seed_1337,SST-2-seed_42	CoLA-seed_1337,SST-2-seed_71	CoLA-seed_1337,SST-2-seed_86	CoLA-seed_166,SST-2-seed_42	CoLA-seed_166,SST-2-seed_71	CoLA-seed_166,SST-2-seed_86	CoLA-seed_42,SST-2-seed_71	CoLA-seed_71,SST-2-seed_86
#
#
#
# CoLA,STS-B
# ---------------------------------------------------------------------
# p-value: 0.0065106077463491
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 5
# Total mask pairs - 10
# Percentage - 0.5
#
# Similar Mask Pairs:
#
# CoLA-seed_1337,STS-B-seed_166	CoLA-seed_1337,STS-B-seed_86	CoLA-seed_166,STS-B-seed_42	CoLA-seed_166,STS-B-seed_86	CoLA-seed_71,STS-B-seed_86
#
#
#
# CoLA,WNLI
# ---------------------------------------------------------------------
# p-value: 2.607761098045302e-16
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# HANS,HANS_MNLI
# ---------------------------------------------------------------------
# p-value: 0.9934656221037506
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,HANS_MNLI-seed_166	HANS-seed_1337,HANS_MNLI-seed_42	HANS-seed_1337,HANS_MNLI-seed_71	HANS-seed_1337,HANS_MNLI-seed_86	HANS-seed_166,HANS_MNLI-seed_42	HANS-seed_166,HANS_MNLI-seed_71	HANS-seed_166,HANS_MNLI-seed_86	HANS-seed_42,HANS_MNLI-seed_71	HANS-seed_42,HANS_MNLI-seed_86	HANS-seed_71,HANS_MNLI-seed_86
#
#
#
# HANS,MNLI
# ---------------------------------------------------------------------
# p-value: 0.9675512331279599
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MNLI-seed_166	HANS-seed_1337,MNLI-seed_42	HANS-seed_1337,MNLI-seed_71	HANS-seed_1337,MNLI-seed_86	HANS-seed_166,MNLI-seed_42	HANS-seed_166,MNLI-seed_71	HANS-seed_166,MNLI-seed_86	HANS-seed_42,MNLI-seed_71	HANS-seed_42,MNLI-seed_86	HANS-seed_71,MNLI-seed_86
#
#
#
# HANS,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.9737463870351463
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MNLI_TWO-seed_166	HANS-seed_1337,MNLI_TWO-seed_42	HANS-seed_1337,MNLI_TWO-seed_71	HANS-seed_1337,MNLI_TWO-seed_86	HANS-seed_166,MNLI_TWO-seed_42	HANS-seed_166,MNLI_TWO-seed_71	HANS-seed_166,MNLI_TWO-seed_86	HANS-seed_42,MNLI_TWO-seed_71	HANS-seed_42,MNLI_TWO-seed_86	HANS-seed_71,MNLI_TWO-seed_86
#
#
#
# HANS,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.9265918861074233
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MNLI_TWO_HALF-seed_166	HANS-seed_1337,MNLI_TWO_HALF-seed_42	HANS-seed_1337,MNLI_TWO_HALF-seed_71	HANS-seed_1337,MNLI_TWO_HALF-seed_86	HANS-seed_166,MNLI_TWO_HALF-seed_42	HANS-seed_166,MNLI_TWO_HALF-seed_71	HANS-seed_166,MNLI_TWO_HALF-seed_86	HANS-seed_42,MNLI_TWO_HALF-seed_71	HANS-seed_42,MNLI_TWO_HALF-seed_86	HANS-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# HANS,MRPC
# ---------------------------------------------------------------------
# p-value: 0.7145344264228417
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,MRPC-seed_166	HANS-seed_1337,MRPC-seed_42	HANS-seed_1337,MRPC-seed_71	HANS-seed_1337,MRPC-seed_86	HANS-seed_166,MRPC-seed_42	HANS-seed_166,MRPC-seed_71	HANS-seed_166,MRPC-seed_86	HANS-seed_42,MRPC-seed_71	HANS-seed_42,MRPC-seed_86	HANS-seed_71,MRPC-seed_86
#
#
#
# HANS,QNLI
# ---------------------------------------------------------------------
# p-value: 0.946636958767037
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,QNLI-seed_166	HANS-seed_1337,QNLI-seed_42	HANS-seed_1337,QNLI-seed_71	HANS-seed_1337,QNLI-seed_86	HANS-seed_166,QNLI-seed_42	HANS-seed_166,QNLI-seed_71	HANS-seed_166,QNLI-seed_86	HANS-seed_42,QNLI-seed_71	HANS-seed_42,QNLI-seed_86	HANS-seed_71,QNLI-seed_86
#
#
#
# HANS,QQP
# ---------------------------------------------------------------------
# p-value: 0.9732184150304131
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,QQP-seed_166	HANS-seed_1337,QQP-seed_42	HANS-seed_1337,QQP-seed_71	HANS-seed_1337,QQP-seed_86	HANS-seed_166,QQP-seed_42	HANS-seed_166,QQP-seed_71	HANS-seed_166,QQP-seed_86	HANS-seed_42,QQP-seed_71	HANS-seed_42,QQP-seed_86	HANS-seed_71,QQP-seed_86
#
#
#
# HANS,RTE
# ---------------------------------------------------------------------
# p-value: 0.41442027190513975
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,RTE-seed_166	HANS-seed_1337,RTE-seed_42	HANS-seed_1337,RTE-seed_71	HANS-seed_1337,RTE-seed_86	HANS-seed_166,RTE-seed_42	HANS-seed_166,RTE-seed_71	HANS-seed_166,RTE-seed_86	HANS-seed_42,RTE-seed_71	HANS-seed_42,RTE-seed_86	HANS-seed_71,RTE-seed_86
#
#
#
# HANS,SST-2
# ---------------------------------------------------------------------
# p-value: 0.9940479580983713
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,SST-2-seed_166	HANS-seed_1337,SST-2-seed_42	HANS-seed_1337,SST-2-seed_71	HANS-seed_1337,SST-2-seed_86	HANS-seed_166,SST-2-seed_42	HANS-seed_166,SST-2-seed_71	HANS-seed_166,SST-2-seed_86	HANS-seed_42,SST-2-seed_71	HANS-seed_42,SST-2-seed_86	HANS-seed_71,SST-2-seed_86
#
#
#
# HANS,STS-B
# ---------------------------------------------------------------------
# p-value: 0.8686258051534866
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS-seed_1337,STS-B-seed_166	HANS-seed_1337,STS-B-seed_42	HANS-seed_1337,STS-B-seed_71	HANS-seed_1337,STS-B-seed_86	HANS-seed_166,STS-B-seed_42	HANS-seed_166,STS-B-seed_71	HANS-seed_166,STS-B-seed_86	HANS-seed_42,STS-B-seed_71	HANS-seed_42,STS-B-seed_86	HANS-seed_71,STS-B-seed_86
#
#
#
# HANS,WNLI
# ---------------------------------------------------------------------
# p-value: 8.817779020880703e-09
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# HANS_MNLI,MNLI
# ---------------------------------------------------------------------
# p-value: 0.9942499454202949
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MNLI-seed_166	HANS_MNLI-seed_1337,MNLI-seed_42	HANS_MNLI-seed_1337,MNLI-seed_71	HANS_MNLI-seed_1337,MNLI-seed_86	HANS_MNLI-seed_166,MNLI-seed_42	HANS_MNLI-seed_166,MNLI-seed_71	HANS_MNLI-seed_166,MNLI-seed_86	HANS_MNLI-seed_42,MNLI-seed_71	HANS_MNLI-seed_42,MNLI-seed_86	HANS_MNLI-seed_71,MNLI-seed_86
#
#
#
# HANS_MNLI,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.9918474515047692
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MNLI_TWO-seed_166	HANS_MNLI-seed_1337,MNLI_TWO-seed_42	HANS_MNLI-seed_1337,MNLI_TWO-seed_71	HANS_MNLI-seed_1337,MNLI_TWO-seed_86	HANS_MNLI-seed_166,MNLI_TWO-seed_42	HANS_MNLI-seed_166,MNLI_TWO-seed_71	HANS_MNLI-seed_166,MNLI_TWO-seed_86	HANS_MNLI-seed_42,MNLI_TWO-seed_71	HANS_MNLI-seed_42,MNLI_TWO-seed_86	HANS_MNLI-seed_71,MNLI_TWO-seed_86
#
#
#
# HANS_MNLI,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.9613231304491389
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_166	HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_42	HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_71	HANS_MNLI-seed_1337,MNLI_TWO_HALF-seed_86	HANS_MNLI-seed_166,MNLI_TWO_HALF-seed_42	HANS_MNLI-seed_166,MNLI_TWO_HALF-seed_71	HANS_MNLI-seed_166,MNLI_TWO_HALF-seed_86	HANS_MNLI-seed_42,MNLI_TWO_HALF-seed_71	HANS_MNLI-seed_42,MNLI_TWO_HALF-seed_86	HANS_MNLI-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# HANS_MNLI,MRPC
# ---------------------------------------------------------------------
# p-value: 0.9254550668603317
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,MRPC-seed_166	HANS_MNLI-seed_1337,MRPC-seed_42	HANS_MNLI-seed_1337,MRPC-seed_71	HANS_MNLI-seed_1337,MRPC-seed_86	HANS_MNLI-seed_166,MRPC-seed_42	HANS_MNLI-seed_166,MRPC-seed_71	HANS_MNLI-seed_166,MRPC-seed_86	HANS_MNLI-seed_42,MRPC-seed_71	HANS_MNLI-seed_42,MRPC-seed_86	HANS_MNLI-seed_71,MRPC-seed_86
#
#
#
# HANS_MNLI,QNLI
# ---------------------------------------------------------------------
# p-value: 0.997838044377814
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,QNLI-seed_166	HANS_MNLI-seed_1337,QNLI-seed_42	HANS_MNLI-seed_1337,QNLI-seed_71	HANS_MNLI-seed_1337,QNLI-seed_86	HANS_MNLI-seed_166,QNLI-seed_42	HANS_MNLI-seed_166,QNLI-seed_71	HANS_MNLI-seed_166,QNLI-seed_86	HANS_MNLI-seed_42,QNLI-seed_71	HANS_MNLI-seed_42,QNLI-seed_86	HANS_MNLI-seed_71,QNLI-seed_86
#
#
#
# HANS_MNLI,QQP
# ---------------------------------------------------------------------
# p-value: 0.9990519328550024
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,QQP-seed_166	HANS_MNLI-seed_1337,QQP-seed_42	HANS_MNLI-seed_1337,QQP-seed_71	HANS_MNLI-seed_1337,QQP-seed_86	HANS_MNLI-seed_166,QQP-seed_42	HANS_MNLI-seed_166,QQP-seed_71	HANS_MNLI-seed_166,QQP-seed_86	HANS_MNLI-seed_42,QQP-seed_71	HANS_MNLI-seed_42,QQP-seed_86	HANS_MNLI-seed_71,QQP-seed_86
#
#
#
# HANS_MNLI,RTE
# ---------------------------------------------------------------------
# p-value: 0.6300091812672219
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,RTE-seed_166	HANS_MNLI-seed_1337,RTE-seed_42	HANS_MNLI-seed_1337,RTE-seed_71	HANS_MNLI-seed_1337,RTE-seed_86	HANS_MNLI-seed_166,RTE-seed_42	HANS_MNLI-seed_166,RTE-seed_71	HANS_MNLI-seed_166,RTE-seed_86	HANS_MNLI-seed_42,RTE-seed_71	HANS_MNLI-seed_42,RTE-seed_86	HANS_MNLI-seed_71,RTE-seed_86
#
#
#
# HANS_MNLI,SST-2
# ---------------------------------------------------------------------
# p-value: 0.9948599199728254
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,SST-2-seed_166	HANS_MNLI-seed_1337,SST-2-seed_42	HANS_MNLI-seed_1337,SST-2-seed_71	HANS_MNLI-seed_1337,SST-2-seed_86	HANS_MNLI-seed_166,SST-2-seed_42	HANS_MNLI-seed_166,SST-2-seed_71	HANS_MNLI-seed_166,SST-2-seed_86	HANS_MNLI-seed_42,SST-2-seed_71	HANS_MNLI-seed_42,SST-2-seed_86	HANS_MNLI-seed_71,SST-2-seed_86
#
#
#
# HANS_MNLI,STS-B
# ---------------------------------------------------------------------
# p-value: 0.8193956767023852
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# HANS_MNLI-seed_1337,STS-B-seed_166	HANS_MNLI-seed_1337,STS-B-seed_42	HANS_MNLI-seed_1337,STS-B-seed_71	HANS_MNLI-seed_1337,STS-B-seed_86	HANS_MNLI-seed_166,STS-B-seed_42	HANS_MNLI-seed_166,STS-B-seed_71	HANS_MNLI-seed_166,STS-B-seed_86	HANS_MNLI-seed_42,STS-B-seed_71	HANS_MNLI-seed_42,STS-B-seed_86	HANS_MNLI-seed_71,STS-B-seed_86
#
#
#
# HANS_MNLI,WNLI
# ---------------------------------------------------------------------
# p-value: 3.412285479935219e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI,MNLI_TWO
# ---------------------------------------------------------------------
# p-value: 0.9690688764624906
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI_TWO-seed_166	MNLI-seed_1337,MNLI_TWO-seed_42	MNLI-seed_1337,MNLI_TWO-seed_71	MNLI-seed_1337,MNLI_TWO-seed_86	MNLI-seed_166,MNLI_TWO-seed_42	MNLI-seed_166,MNLI_TWO-seed_71	MNLI-seed_166,MNLI_TWO-seed_86	MNLI-seed_42,MNLI_TWO-seed_71	MNLI-seed_42,MNLI_TWO-seed_86	MNLI-seed_71,MNLI_TWO-seed_86
#
#
#
# MNLI,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.9342133007236266
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MNLI_TWO_HALF-seed_166	MNLI-seed_1337,MNLI_TWO_HALF-seed_42	MNLI-seed_1337,MNLI_TWO_HALF-seed_71	MNLI-seed_1337,MNLI_TWO_HALF-seed_86	MNLI-seed_166,MNLI_TWO_HALF-seed_42	MNLI-seed_166,MNLI_TWO_HALF-seed_71	MNLI-seed_166,MNLI_TWO_HALF-seed_86	MNLI-seed_42,MNLI_TWO_HALF-seed_71	MNLI-seed_42,MNLI_TWO_HALF-seed_86	MNLI-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MNLI,MRPC
# ---------------------------------------------------------------------
# p-value: 0.8922371858901061
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,MRPC-seed_166	MNLI-seed_1337,MRPC-seed_42	MNLI-seed_1337,MRPC-seed_71	MNLI-seed_1337,MRPC-seed_86	MNLI-seed_166,MRPC-seed_42	MNLI-seed_166,MRPC-seed_71	MNLI-seed_166,MRPC-seed_86	MNLI-seed_42,MRPC-seed_71	MNLI-seed_42,MRPC-seed_86	MNLI-seed_71,MRPC-seed_86
#
#
#
# MNLI,QNLI
# ---------------------------------------------------------------------
# p-value: 0.9928984042031119
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,QNLI-seed_166	MNLI-seed_1337,QNLI-seed_42	MNLI-seed_1337,QNLI-seed_71	MNLI-seed_1337,QNLI-seed_86	MNLI-seed_166,QNLI-seed_42	MNLI-seed_166,QNLI-seed_71	MNLI-seed_166,QNLI-seed_86	MNLI-seed_42,QNLI-seed_71	MNLI-seed_42,QNLI-seed_86	MNLI-seed_71,QNLI-seed_86
#
#
#
# MNLI,QQP
# ---------------------------------------------------------------------
# p-value: 0.9929323893725319
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,QQP-seed_166	MNLI-seed_1337,QQP-seed_42	MNLI-seed_1337,QQP-seed_71	MNLI-seed_1337,QQP-seed_86	MNLI-seed_166,QQP-seed_42	MNLI-seed_166,QQP-seed_71	MNLI-seed_166,QQP-seed_86	MNLI-seed_42,QQP-seed_71	MNLI-seed_42,QQP-seed_86	MNLI-seed_71,QQP-seed_86
#
#
#
# MNLI,RTE
# ---------------------------------------------------------------------
# p-value: 0.5501863355202783
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,RTE-seed_166	MNLI-seed_1337,RTE-seed_42	MNLI-seed_1337,RTE-seed_71	MNLI-seed_1337,RTE-seed_86	MNLI-seed_166,RTE-seed_42	MNLI-seed_166,RTE-seed_71	MNLI-seed_166,RTE-seed_86	MNLI-seed_42,RTE-seed_71	MNLI-seed_42,RTE-seed_86	MNLI-seed_71,RTE-seed_86
#
#
#
# MNLI,SST-2
# ---------------------------------------------------------------------
# p-value: 0.9730551948560341
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,SST-2-seed_166	MNLI-seed_1337,SST-2-seed_42	MNLI-seed_1337,SST-2-seed_71	MNLI-seed_1337,SST-2-seed_86	MNLI-seed_166,SST-2-seed_42	MNLI-seed_166,SST-2-seed_71	MNLI-seed_166,SST-2-seed_86	MNLI-seed_42,SST-2-seed_71	MNLI-seed_42,SST-2-seed_86	MNLI-seed_71,SST-2-seed_86
#
#
#
# MNLI,STS-B
# ---------------------------------------------------------------------
# p-value: 0.7385711131768098
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI-seed_1337,STS-B-seed_166	MNLI-seed_1337,STS-B-seed_42	MNLI-seed_1337,STS-B-seed_71	MNLI-seed_1337,STS-B-seed_86	MNLI-seed_166,STS-B-seed_42	MNLI-seed_166,STS-B-seed_71	MNLI-seed_166,STS-B-seed_86	MNLI-seed_42,STS-B-seed_71	MNLI-seed_42,STS-B-seed_86	MNLI-seed_71,STS-B-seed_86
#
#
#
# MNLI,WNLI
# ---------------------------------------------------------------------
# p-value: 2.117305819153778e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI_TWO,MNLI_TWO_HALF
# ---------------------------------------------------------------------
# p-value: 0.8923985132359082
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MNLI_TWO_HALF-seed_166	MNLI_TWO-seed_1337,MNLI_TWO_HALF-seed_42	MNLI_TWO-seed_1337,MNLI_TWO_HALF-seed_71	MNLI_TWO-seed_1337,MNLI_TWO_HALF-seed_86	MNLI_TWO-seed_166,MNLI_TWO_HALF-seed_42	MNLI_TWO-seed_166,MNLI_TWO_HALF-seed_71	MNLI_TWO-seed_166,MNLI_TWO_HALF-seed_86	MNLI_TWO-seed_42,MNLI_TWO_HALF-seed_71	MNLI_TWO-seed_42,MNLI_TWO_HALF-seed_86	MNLI_TWO-seed_71,MNLI_TWO_HALF-seed_86
#
#
#
# MNLI_TWO,MRPC
# ---------------------------------------------------------------------
# p-value: 0.8462561097828335
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,MRPC-seed_166	MNLI_TWO-seed_1337,MRPC-seed_42	MNLI_TWO-seed_1337,MRPC-seed_71	MNLI_TWO-seed_1337,MRPC-seed_86	MNLI_TWO-seed_166,MRPC-seed_42	MNLI_TWO-seed_166,MRPC-seed_71	MNLI_TWO-seed_166,MRPC-seed_86	MNLI_TWO-seed_42,MRPC-seed_71	MNLI_TWO-seed_42,MRPC-seed_86	MNLI_TWO-seed_71,MRPC-seed_86
#
#
#
# MNLI_TWO,QNLI
# ---------------------------------------------------------------------
# p-value: 0.9854681726511558
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,QNLI-seed_166	MNLI_TWO-seed_1337,QNLI-seed_42	MNLI_TWO-seed_1337,QNLI-seed_71	MNLI_TWO-seed_1337,QNLI-seed_86	MNLI_TWO-seed_166,QNLI-seed_42	MNLI_TWO-seed_166,QNLI-seed_71	MNLI_TWO-seed_166,QNLI-seed_86	MNLI_TWO-seed_42,QNLI-seed_71	MNLI_TWO-seed_42,QNLI-seed_86	MNLI_TWO-seed_71,QNLI-seed_86
#
#
#
# MNLI_TWO,QQP
# ---------------------------------------------------------------------
# p-value: 0.9896713090641862
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,QQP-seed_166	MNLI_TWO-seed_1337,QQP-seed_42	MNLI_TWO-seed_1337,QQP-seed_71	MNLI_TWO-seed_1337,QQP-seed_86	MNLI_TWO-seed_166,QQP-seed_42	MNLI_TWO-seed_166,QQP-seed_71	MNLI_TWO-seed_166,QQP-seed_86	MNLI_TWO-seed_42,QQP-seed_71	MNLI_TWO-seed_42,QQP-seed_86	MNLI_TWO-seed_71,QQP-seed_86
#
#
#
# MNLI_TWO,RTE
# ---------------------------------------------------------------------
# p-value: 0.5473425905242573
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,RTE-seed_166	MNLI_TWO-seed_1337,RTE-seed_71	MNLI_TWO-seed_1337,RTE-seed_86	MNLI_TWO-seed_166,RTE-seed_42	MNLI_TWO-seed_166,RTE-seed_71	MNLI_TWO-seed_166,RTE-seed_86	MNLI_TWO-seed_42,RTE-seed_71	MNLI_TWO-seed_42,RTE-seed_86	MNLI_TWO-seed_71,RTE-seed_86
#
#
#
# MNLI_TWO,SST-2
# ---------------------------------------------------------------------
# p-value: 0.9774395925653675
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,SST-2-seed_166	MNLI_TWO-seed_1337,SST-2-seed_42	MNLI_TWO-seed_1337,SST-2-seed_71	MNLI_TWO-seed_1337,SST-2-seed_86	MNLI_TWO-seed_166,SST-2-seed_42	MNLI_TWO-seed_166,SST-2-seed_71	MNLI_TWO-seed_166,SST-2-seed_86	MNLI_TWO-seed_42,SST-2-seed_71	MNLI_TWO-seed_42,SST-2-seed_86	MNLI_TWO-seed_71,SST-2-seed_86
#
#
#
# MNLI_TWO,STS-B
# ---------------------------------------------------------------------
# p-value: 0.7457340064847695
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO-seed_1337,STS-B-seed_166	MNLI_TWO-seed_1337,STS-B-seed_42	MNLI_TWO-seed_1337,STS-B-seed_71	MNLI_TWO-seed_1337,STS-B-seed_86	MNLI_TWO-seed_166,STS-B-seed_42	MNLI_TWO-seed_166,STS-B-seed_71	MNLI_TWO-seed_166,STS-B-seed_86	MNLI_TWO-seed_42,STS-B-seed_71	MNLI_TWO-seed_42,STS-B-seed_86	MNLI_TWO-seed_71,STS-B-seed_86
#
#
#
# MNLI_TWO,WNLI
# ---------------------------------------------------------------------
# p-value: 3.090856126381112e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MNLI_TWO_HALF,MRPC
# ---------------------------------------------------------------------
# p-value: 0.7512232895282782
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,MRPC-seed_166	MNLI_TWO_HALF-seed_1337,MRPC-seed_42	MNLI_TWO_HALF-seed_1337,MRPC-seed_71	MNLI_TWO_HALF-seed_1337,MRPC-seed_86	MNLI_TWO_HALF-seed_166,MRPC-seed_42	MNLI_TWO_HALF-seed_166,MRPC-seed_71	MNLI_TWO_HALF-seed_166,MRPC-seed_86	MNLI_TWO_HALF-seed_42,MRPC-seed_71	MNLI_TWO_HALF-seed_42,MRPC-seed_86
#
#
#
# MNLI_TWO_HALF,QNLI
# ---------------------------------------------------------------------
# p-value: 0.9312284236145514
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,QNLI-seed_166	MNLI_TWO_HALF-seed_1337,QNLI-seed_42	MNLI_TWO_HALF-seed_1337,QNLI-seed_71	MNLI_TWO_HALF-seed_1337,QNLI-seed_86	MNLI_TWO_HALF-seed_166,QNLI-seed_42	MNLI_TWO_HALF-seed_166,QNLI-seed_71	MNLI_TWO_HALF-seed_166,QNLI-seed_86	MNLI_TWO_HALF-seed_42,QNLI-seed_71	MNLI_TWO_HALF-seed_42,QNLI-seed_86	MNLI_TWO_HALF-seed_71,QNLI-seed_86
#
#
#
# MNLI_TWO_HALF,QQP
# ---------------------------------------------------------------------
# p-value: 0.9524939169129172
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,QQP-seed_166	MNLI_TWO_HALF-seed_1337,QQP-seed_42	MNLI_TWO_HALF-seed_1337,QQP-seed_71	MNLI_TWO_HALF-seed_1337,QQP-seed_86	MNLI_TWO_HALF-seed_166,QQP-seed_42	MNLI_TWO_HALF-seed_166,QQP-seed_71	MNLI_TWO_HALF-seed_166,QQP-seed_86	MNLI_TWO_HALF-seed_42,QQP-seed_71	MNLI_TWO_HALF-seed_42,QQP-seed_86	MNLI_TWO_HALF-seed_71,QQP-seed_86
#
#
#
# MNLI_TWO_HALF,RTE
# ---------------------------------------------------------------------
# p-value: 0.4775409663485035
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,RTE-seed_166	MNLI_TWO_HALF-seed_1337,RTE-seed_42	MNLI_TWO_HALF-seed_1337,RTE-seed_71	MNLI_TWO_HALF-seed_1337,RTE-seed_86	MNLI_TWO_HALF-seed_166,RTE-seed_42	MNLI_TWO_HALF-seed_166,RTE-seed_71	MNLI_TWO_HALF-seed_166,RTE-seed_86	MNLI_TWO_HALF-seed_42,RTE-seed_71	MNLI_TWO_HALF-seed_42,RTE-seed_86	MNLI_TWO_HALF-seed_71,RTE-seed_86
#
#
#
# MNLI_TWO_HALF,SST-2
# ---------------------------------------------------------------------
# p-value: 0.9142816903751808
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,SST-2-seed_166	MNLI_TWO_HALF-seed_1337,SST-2-seed_42	MNLI_TWO_HALF-seed_1337,SST-2-seed_71	MNLI_TWO_HALF-seed_1337,SST-2-seed_86	MNLI_TWO_HALF-seed_166,SST-2-seed_42	MNLI_TWO_HALF-seed_166,SST-2-seed_71	MNLI_TWO_HALF-seed_42,SST-2-seed_71	MNLI_TWO_HALF-seed_42,SST-2-seed_86	MNLI_TWO_HALF-seed_71,SST-2-seed_86
#
#
#
# MNLI_TWO_HALF,STS-B
# ---------------------------------------------------------------------
# p-value: 0.6350370215752201
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MNLI_TWO_HALF-seed_1337,STS-B-seed_166	MNLI_TWO_HALF-seed_1337,STS-B-seed_42	MNLI_TWO_HALF-seed_1337,STS-B-seed_71	MNLI_TWO_HALF-seed_1337,STS-B-seed_86	MNLI_TWO_HALF-seed_166,STS-B-seed_42	MNLI_TWO_HALF-seed_166,STS-B-seed_71	MNLI_TWO_HALF-seed_166,STS-B-seed_86	MNLI_TWO_HALF-seed_42,STS-B-seed_71	MNLI_TWO_HALF-seed_42,STS-B-seed_86	MNLI_TWO_HALF-seed_71,STS-B-seed_86
#
#
#
# MNLI_TWO_HALF,WNLI
# ---------------------------------------------------------------------
# p-value: 8.360081725200201e-11
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# MRPC,QNLI
# ---------------------------------------------------------------------
# p-value: 0.9702271293149509
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,QNLI-seed_166	MRPC-seed_1337,QNLI-seed_42	MRPC-seed_1337,QNLI-seed_71	MRPC-seed_1337,QNLI-seed_86	MRPC-seed_166,QNLI-seed_42	MRPC-seed_166,QNLI-seed_71	MRPC-seed_166,QNLI-seed_86	MRPC-seed_42,QNLI-seed_71	MRPC-seed_42,QNLI-seed_86	MRPC-seed_71,QNLI-seed_86
#
#
#
# MRPC,QQP
# ---------------------------------------------------------------------
# p-value: 0.9518824772793133
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,QQP-seed_166	MRPC-seed_1337,QQP-seed_42	MRPC-seed_1337,QQP-seed_71	MRPC-seed_1337,QQP-seed_86	MRPC-seed_166,QQP-seed_42	MRPC-seed_166,QQP-seed_71	MRPC-seed_166,QQP-seed_86	MRPC-seed_42,QQP-seed_71	MRPC-seed_42,QQP-seed_86	MRPC-seed_71,QQP-seed_86
#
#
#
# MRPC,RTE
# ---------------------------------------------------------------------
# p-value: 0.5501863355202783
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,RTE-seed_166	MRPC-seed_1337,RTE-seed_42	MRPC-seed_1337,RTE-seed_71	MRPC-seed_1337,RTE-seed_86	MRPC-seed_166,RTE-seed_42	MRPC-seed_166,RTE-seed_71	MRPC-seed_166,RTE-seed_86	MRPC-seed_42,RTE-seed_71	MRPC-seed_42,RTE-seed_86	MRPC-seed_71,RTE-seed_86
#
#
#
# MRPC,SST-2
# ---------------------------------------------------------------------
# p-value: 0.8044828642346866
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,SST-2-seed_166	MRPC-seed_1337,SST-2-seed_42	MRPC-seed_1337,SST-2-seed_71	MRPC-seed_1337,SST-2-seed_86	MRPC-seed_166,SST-2-seed_42	MRPC-seed_166,SST-2-seed_71	MRPC-seed_166,SST-2-seed_86	MRPC-seed_42,SST-2-seed_71	MRPC-seed_42,SST-2-seed_86	MRPC-seed_71,SST-2-seed_86
#
#
#
# MRPC,STS-B
# ---------------------------------------------------------------------
# p-value: 0.375107156829534
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# MRPC-seed_1337,STS-B-seed_166	MRPC-seed_1337,STS-B-seed_42	MRPC-seed_1337,STS-B-seed_71	MRPC-seed_1337,STS-B-seed_86	MRPC-seed_166,STS-B-seed_42	MRPC-seed_166,STS-B-seed_71	MRPC-seed_166,STS-B-seed_86	MRPC-seed_42,STS-B-seed_71	MRPC-seed_42,STS-B-seed_86	MRPC-seed_71,STS-B-seed_86
#
#
#
# MRPC,WNLI
# ---------------------------------------------------------------------
# p-value: 7.378056217068952e-12
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# QNLI,QQP
# ---------------------------------------------------------------------
# p-value: 0.999386038632317
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,QQP-seed_166	QNLI-seed_1337,QQP-seed_42	QNLI-seed_1337,QQP-seed_71	QNLI-seed_1337,QQP-seed_86	QNLI-seed_166,QQP-seed_42	QNLI-seed_166,QQP-seed_71	QNLI-seed_166,QQP-seed_86	QNLI-seed_42,QQP-seed_71	QNLI-seed_42,QQP-seed_86	QNLI-seed_71,QQP-seed_86
#
#
#
# QNLI,RTE
# ---------------------------------------------------------------------
# p-value: 0.7282037362405086
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,RTE-seed_166	QNLI-seed_1337,RTE-seed_42	QNLI-seed_1337,RTE-seed_71	QNLI-seed_1337,RTE-seed_86	QNLI-seed_166,RTE-seed_42	QNLI-seed_166,RTE-seed_71	QNLI-seed_166,RTE-seed_86	QNLI-seed_42,RTE-seed_71	QNLI-seed_42,RTE-seed_86	QNLI-seed_71,RTE-seed_86
#
#
#
# QNLI,SST-2
# ---------------------------------------------------------------------
# p-value: 0.9730954418216329
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,SST-2-seed_166	QNLI-seed_1337,SST-2-seed_42	QNLI-seed_1337,SST-2-seed_71	QNLI-seed_1337,SST-2-seed_86	QNLI-seed_166,SST-2-seed_42	QNLI-seed_166,SST-2-seed_71	QNLI-seed_166,SST-2-seed_86	QNLI-seed_42,SST-2-seed_71	QNLI-seed_42,SST-2-seed_86	QNLI-seed_71,SST-2-seed_86
#
#
#
# QNLI,STS-B
# ---------------------------------------------------------------------
# p-value: 0.6976410764593743
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 9
# Total mask pairs - 10
# Percentage - 0.9
#
# Similar Mask Pairs:
#
# QNLI-seed_1337,STS-B-seed_166	QNLI-seed_1337,STS-B-seed_42	QNLI-seed_1337,STS-B-seed_71	QNLI-seed_1337,STS-B-seed_86	QNLI-seed_166,STS-B-seed_42	QNLI-seed_166,STS-B-seed_71	QNLI-seed_166,STS-B-seed_86	QNLI-seed_42,STS-B-seed_86	QNLI-seed_71,STS-B-seed_86
#
#
#
# QNLI,WNLI
# ---------------------------------------------------------------------
# p-value: 5.157457575709253e-11
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# QQP,RTE
# ---------------------------------------------------------------------
# p-value: 0.7275185377333018
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QQP-seed_1337,RTE-seed_166	QQP-seed_1337,RTE-seed_42	QQP-seed_1337,RTE-seed_71	QQP-seed_1337,RTE-seed_86	QQP-seed_166,RTE-seed_42	QQP-seed_166,RTE-seed_71	QQP-seed_166,RTE-seed_86	QQP-seed_42,RTE-seed_71	QQP-seed_42,RTE-seed_86	QQP-seed_71,RTE-seed_86
#
#
#
# QQP,SST-2
# ---------------------------------------------------------------------
# p-value: 0.982881114110208
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QQP-seed_1337,SST-2-seed_166	QQP-seed_1337,SST-2-seed_42	QQP-seed_1337,SST-2-seed_71	QQP-seed_1337,SST-2-seed_86	QQP-seed_166,SST-2-seed_42	QQP-seed_166,SST-2-seed_71	QQP-seed_166,SST-2-seed_86	QQP-seed_42,SST-2-seed_71	QQP-seed_42,SST-2-seed_86	QQP-seed_71,SST-2-seed_86
#
#
#
# QQP,STS-B
# ---------------------------------------------------------------------
# p-value: 0.7564762011090719
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# QQP-seed_1337,STS-B-seed_166	QQP-seed_1337,STS-B-seed_42	QQP-seed_1337,STS-B-seed_71	QQP-seed_1337,STS-B-seed_86	QQP-seed_166,STS-B-seed_42	QQP-seed_166,STS-B-seed_71	QQP-seed_166,STS-B-seed_86	QQP-seed_42,STS-B-seed_71	QQP-seed_42,STS-B-seed_86	QQP-seed_71,STS-B-seed_86
#
#
#
# QQP,WNLI
# ---------------------------------------------------------------------
# p-value: 2.598885180175548e-10
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# RTE,SST-2
# ---------------------------------------------------------------------
# p-value: 0.5691906497334984
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# RTE-seed_1337,SST-2-seed_166	RTE-seed_1337,SST-2-seed_42	RTE-seed_1337,SST-2-seed_71	RTE-seed_1337,SST-2-seed_86	RTE-seed_166,SST-2-seed_42	RTE-seed_166,SST-2-seed_71	RTE-seed_166,SST-2-seed_86	RTE-seed_42,SST-2-seed_71	RTE-seed_42,SST-2-seed_86	RTE-seed_71,SST-2-seed_86
#
#
#
# RTE,STS-B
# ---------------------------------------------------------------------
# p-value: 0.22308151425243802
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 8
# Total mask pairs - 10
# Percentage - 0.8
#
# Similar Mask Pairs:
#
# RTE-seed_1337,STS-B-seed_166	RTE-seed_1337,STS-B-seed_42	RTE-seed_1337,STS-B-seed_86	RTE-seed_166,STS-B-seed_42	RTE-seed_166,STS-B-seed_71	RTE-seed_166,STS-B-seed_86	RTE-seed_42,STS-B-seed_86	RTE-seed_71,STS-B-seed_86
#
#
#
# RTE,WNLI
# ---------------------------------------------------------------------
# p-value: 4.5972943666139745e-12
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# SST-2,STS-B
# ---------------------------------------------------------------------
# p-value: 0.860526678065856
# Null hypothesis (all seeds are similar) is not rejected.
# Total mask pairs where Null hypothesis is not rejected - 10
# Total mask pairs - 10
# Percentage - 1.0
#
# Similar Mask Pairs:
#
# SST-2-seed_1337,STS-B-seed_166	SST-2-seed_1337,STS-B-seed_42	SST-2-seed_1337,STS-B-seed_71	SST-2-seed_1337,STS-B-seed_86	SST-2-seed_166,STS-B-seed_42	SST-2-seed_166,STS-B-seed_71	SST-2-seed_166,STS-B-seed_86	SST-2-seed_42,STS-B-seed_71	SST-2-seed_42,STS-B-seed_86	SST-2-seed_71,STS-B-seed_86
#
#
#
# SST-2,WNLI
# ---------------------------------------------------------------------
# p-value: 6.463910932533267e-09
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
#
#
#
#
#
# STS-B,WNLI
# ---------------------------------------------------------------------
# p-value: 9.860812161468573e-09
# Null hypothesis (all seeds are similar) is rejected.
# Total mask pairs where Null hypothesis is not rejected - 0
# Total mask pairs - 10
# Percentage - 0.0
#
# Similar Mask Pairs:
